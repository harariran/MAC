# %% [markdown]
# Authors: Ran Harari and Adi Amuzig
# E-mails: [srharari@campus.technion.ac.il](srharari@campus.technion.ac.il),
#          [adi.amuzig@campus.technion.ac.il](mailto:adi.amuzig@campus.technion.ac.il)

# %% [markdown]
# # Emergent Communication
#
# Because the real world is dynamic and continually changing, many real-world scenarios demand coordination among different actors, and having a centralized system to oversee all actions is not possible in a large-scale environment.
#
# Furthermore, communication is quite beneficial in resolving the coordination challenge. In theory, we could simply transfer sensory data among robots, but this would be a lot of information that would be irrelevant because each unit will perceive the world differently owing to its location and sensors.
#
# The interaction between two agents with communication abilities follows a typical cycle with three levels: sensori-motor, conseptual, and language. The cycle is as follows:
#
# 1. **Grounding** - Both agents precive the world and creating a world model (sensori-motor level)
# 2. **Conceptualization** - The speaker determines which information is most useful to the listener in order for the mission to succeed and builds a semantic framework (conceptual level)
# 3. **Production** - conveying a message of semantic experience through verbal or implicit behaviors (language level)
# 4. **Comprehension** - The communication is received and analyzed by the listener into a semantic form (language level)
# 5. **Interpretation** - interpreting the semantic structure in reference to one's own world model and carrying out the appropriate action (conceptual level)
#
# ![Communication Cycle](images/emergent_com_theory.png)
# [A Practical Guide to Studying Emergent Communication through Grounded Language Games - Nevens, Eecke and Beuls]
#
# When it comes to communication, there are two primary options:
#
# - A pre-defined communication protocol, which means that all communication and the actions that occur from that communication are programmed into the system. Before the system goes live, all aspects of the communication cycle are fully specified.
# - Emergent communication is the study of how a communication system emerges among previously uncommunicative individuals. To put it another way, at least some components of the communication cycle must be learned. It is important to note that emergent communication necessitates many interactions between the same agent in order to *learn* a functional communication system.

# %% [markdown]
# ## The Importance of communication
#
# Communication in general is helpful in a multi-robot system for both robot cooperation and human robot collaboration. This session will concentrate on the former.
#
# To investigate the role of communication, we used the multitaxi domain to create a situation with no communication between the agents. To confirm that our communication strategy worked, we first solved the multitaxi domain without communication and demonstrated that it works.

# %%
import math

from src.Communication.COM_net import COM_net
from src.agents.agent import DecisionMaker, Action_message_agent, Agent_Com, RandomDecisionMaker
from src.control.Controller_COM import DecentralizedComController
from src.decision_makers.planners.map_planner import AstarDM
from src.environments.env_wrapper import EnvWrappper, TAXI_pickup_dropoff_REWARDS
from multi_taxi import MultiTaxiEnv



MAP2 = [
    "+-------+",
    "| : |F: |",
    "| : | : |",
    "| : : : |",
    "| | :G| |",
    "+-------+",
]

MAP = [
    "+-----------------------+",
    "| : |F: | : | : | : |F: |",
    "| : | : : : | : | : | : |",
    "| : : : : : : : : : : : |",
    "| : : : : : | : : : : : |",
    "| : : : : : | : : : : : |",
    "| : : : : : : : : : : : |",
    "| | :G| | | :G| | | : | |",
    "+-----------------------+",
]

"""
Builds Multi_taxi env
"""
env = MultiTaxiEnv(num_taxis=2, num_passengers=2, domain_map=MAP, observation_type='symbolic')

env.seed(0)

obs = env.reset()

def build_multi_env(env):
    env.agents = env.taxis_names
    env.action_spaces = {
        agent_name: env.action_space for agent_name in env.agents
    }
    env.observation_spaces = {
        agent_name: env.observation_space for agent_name in env.agents
    }
    env.possible_agents = [agent for agent in env.agents]
    return EnvWrappper(env, env.agents)


environment = build_multi_env(env)
print('EnvironmentWrapper created')

"""
COM-agent - we will explain later
"""

class Heading_message_agent(Agent_Com):

    def __init__(self, decision_maker : AstarDM , sensor_function =None, message_filter = None, AgentName = None, bandW = math.inf, union_recieve = True):
        super().__init__(decision_maker , sensor_function, message_filter, AgentName, bandW, union_recieve)
        self.last_action = None

    def set_data_func(self, obs):
        data = (self.decision_maker.taking_passenger,len(self.decision_maker.active_plan))
        return data

    # todo - implement your recive_func
    def set_recive_func(self, obs, message):
        pass

    # saves last action of the agent - not necessary for com module
    def set_last_action(self, action):
        self.last_action = action

"""
part 1 - 
agents sends com but dont use it - A-star DM solves for each agent
"""
# after having our com-Astar-agents class we can set our env agents into a dicentralized_agents dict
env_agents = environment.get_env_agents()
decentralized_agents = {agent_name: Heading_message_agent(AstarDM(env ,single_plan=True, Taxi_index=int(agent_name[-1]), domain_map=MAP) ,AgentName=agent_name)             # Agent(LearningDecisionMaker(env.action_space))  # can use diffrent DM
                        for agent_name in env_agents}


"""
COM-module - we will explain later
"""
com = COM_net()
""" 
    - MAC controller 
"""
controller = DecentralizedComController(environment, decentralized_agents, com)
"""
activate 
"""
controller.run(render=True, max_iteration=15)
print("Thats all - part 1")
# Out:
# EnvironmentWrapper created
# +-----------------------+
# |D: |F: | : | : | : |F: |
# | : | : : : |P: | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D:_|
# | | :G| | |P:G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (6,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,11), Collided: False
# Passenger1: Location: (1, 6), Destination: (5, 10)
# Passenger2: Location: (6, 5), Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [2, 2]
# active:['(4,)', '(1,)', '(1,)', '(1,)', '(1,)', '(3,)', '(3,)', '(3,)', '(3,)', '(1,)', '(1,)', '(3,)', '(6,)']
# all plans:[['(1,)', '(1,)', '(1,)', '(1,)', '(2,)', '(1,)', '(4,)', '(2,)', '(0,)', '(2,)', '(2,)', '(2,)', '(0,)', '(0,)', '(0,)', '(5,)'], ['(4,)', '(1,)', '(1,)', '(1,)', '(1,)', '(3,)', '(3,)', '(3,)', '(3,)', '(1,)', '(1,)', '(3,)', '(6,)']]
# +-----------------------+
# |D: |F: | : | : | : |F: |
# | : | : : : |P: | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D:_|
# | | :G| | |P:G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (6,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,11), Collided: False
# Passenger1: Location: (1, 6), Destination: (5, 10)
# Passenger2: Location: (6, 5), Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [2, 2]
# active:['(1,)', '(1,)', '(1,)', '(3,)', '(3,)', '(3,)', '(3,)', '(1,)', '(3,)', '(4,)', '(2,)', '(0,)', '(2,)', '(2,)', '(2,)', '(0,)', '(0,)', '(0,)', '(5,)']
# all plans:[['(1,)', '(1,)', '(1,)', '(3,)', '(3,)', '(3,)', '(3,)', '(1,)', '(3,)', '(4,)', '(2,)', '(0,)', '(2,)', '(2,)', '(2,)', '(0,)', '(0,)', '(0,)', '(5,)'], ['(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(0,)', '(4,)', '(1,)', '(1,)', '(1,)', '(1,)', '(3,)', '(3,)', '(3,)', '(3,)', '(1,)', '(1,)', '(3,)', '(6,)']]
# ---------------------------ROUND 1---------------------------------
# taxi_0 obs:
#  MultiDiscrete([ 7 12  7 12  7 12  7 12  7 12  5  5]) , action: 4
# taxi_1 obs:
#  MultiDiscrete([ 7 12  7 12  7 12  7 12  7 12  5  5]) , action: 1
# joint Message: [(2, 12), (1, 18)]
# +-----------------------+
# |D: |F: | : | : | : |F: |
# | : | : : : |P: | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : : |
# | : : : : : | : : : : :_|
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (6,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (4,11), Collided: False
# Passenger1: Location: (1, 6), Destination: (5, 10)
# Passenger2: Location: Taxi1, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [2, 3]
# ---------------------------ROUND 2---------------------------------
# taxi_0 obs:
#  [ 6  5  1  6  6  5  5 10  0  0  2  3  2 12  1 18] , action: 1
# taxi_1 obs:
#  [ 4 11  1  6  6  5  5 10  0  0  2  3  2 12  1 18] , action: 1
# joint Message: [(2, 11), (1, 17)]
# +-----------------------+
# |D: |F: | : | : | : |F: |
# | : | : : : |P: | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :_|
# | : : : : : | : : : : : |
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (3,11), Collided: False
# Passenger1: Location: (1, 6), Destination: (5, 10)
# Passenger2: Location: Taxi1, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [2, 3]
# ---------------------------ROUND 3---------------------------------
# taxi_0 obs:
#  [ 5  5  1  6  6  5  5 10  0  0  2  3  2 11  1 17] , action: 1
# taxi_1 obs:
#  [ 3 11  1  6  6  5  5 10  0  0  2  3  2 11  1 17] , action: 1
# joint Message: [(2, 10), (1, 16)]
# +-----------------------+
# |D: |F: | : | : | : |F: |
# | : | : : : |P: | : | : |
# | : : : : : : : : : : :_|
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,11), Collided: False
# Passenger1: Location: (1, 6), Destination: (5, 10)
# Passenger2: Location: Taxi1, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [2, 3]
# ---------------------------ROUND 4---------------------------------
# taxi_0 obs:
#  [ 4  5  1  6  6  5  5 10  0  0  2  3  2 10  1 16] , action: 1
# taxi_1 obs:
#  [ 2 11  1  6  6  5  5 10  0  0  2  3  2 10  1 16] , action: 3
# joint Message: [(2, 9), (1, 15)]
# +-----------------------+
# |D: |F: | : | : | : |F: |
# | : | : : : |P: | : | : |
# | : : : : : : : : : :_: |
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,10), Collided: False
# Passenger1: Location: (1, 6), Destination: (5, 10)
# Passenger2: Location: Taxi1, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [2, 3]
# ---------------------------ROUND 5---------------------------------
# taxi_0 obs:
#  [ 3  5  1  6  6  5  5 10  0  0  2  3  2  9  1 15] , action: 1
# taxi_1 obs:
#  [ 2 10  1  6  6  5  5 10  0  0  2  3  2  9  1 15] , action: 3
# joint Message: [(2, 8), (1, 14)]
# +-----------------------+
# |D: |F: | : | : | : |F: |
# | : | : : : |P: | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Passenger1: Location: (1, 6), Destination: (5, 10)
# Passenger2: Location: Taxi1, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [2, 3]
# ---------------------------ROUND 6---------------------------------
# taxi_0 obs:
#  [ 2  5  1  6  6  5  5 10  0  0  2  3  2  8  1 14] , action: 3
# taxi_1 obs:
#  [ 2  9  1  6  6  5  5 10  0  0  2  3  2  8  1 14] , action: 3
# joint Message: [(2, 7), (1, 13)]
# +-----------------------+
# |D: |F: | : | : | : |F: |
# | : | : : : |P: | : | : |
# | : : : : : : : :_: : : |
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,4), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,8), Collided: False
# Passenger1: Location: (1, 6), Destination: (5, 10)
# Passenger2: Location: Taxi1, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [2, 3]
# ---------------------------ROUND 7---------------------------------
# taxi_0 obs:
#  [ 2  4  1  6  6  5  5 10  0  0  2  3  2  7  1 13] , action: 3
# taxi_1 obs:
#  [ 2  8  1  6  6  5  5 10  0  0  2  3  2  7  1 13] , action: 3
# joint Message: [(2, 6), (1, 12)]
# +-----------------------+
# |D: |F: | : | : | : |F: |
# | : | : : : |P: | : | : |
# | : : : : : : :_: : : : |
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,3), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,7), Collided: False
# Passenger1: Location: (1, 6), Destination: (5, 10)
# Passenger2: Location: Taxi1, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [2, 3]
# ---------------------------ROUND 8---------------------------------
# taxi_0 obs:
#  [ 2  3  1  6  6  5  5 10  0  0  2  3  2  6  1 12] , action: 3
# taxi_1 obs:
#  [ 2  7  1  6  6  5  5 10  0  0  2  3  2  6  1 12] , action: 1
# joint Message: [(2, 5), (1, 11)]
# +-----------------------+
# |D: |F: | : | : | : |F: |
# | : | : : : |P:_| : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,2), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,7), Collided: False
# Passenger1: Location: (1, 6), Destination: (5, 10)
# Passenger2: Location: Taxi1, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [2, 3]
# ---------------------------ROUND 9---------------------------------
# taxi_0 obs:
#  [ 2  2  1  6  6  5  5 10  0  0  2  3  2  5  1 11] , action: 3
# taxi_1 obs:
#  [ 1  7  1  6  6  5  5 10  0  0  2  3  2  5  1 11] , action: 3
# joint Message: [(2, 4), (1, 10)]
# +-----------------------+
# |D: |F: | : | : | : |F: |
# | : | : : : |P: | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,1), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,6), Collided: False
# Passenger1: Location: (1, 6), Destination: (5, 10)
# Passenger2: Location: Taxi1, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [2, 3]
# ---------------------------ROUND 10---------------------------------
# taxi_0 obs:
#  [ 2  1  1  6  6  5  5 10  0  0  2  3  2  4  1 10] , action: 1
# taxi_1 obs:
#  [ 1  6  1  6  6  5  5 10  0  0  2  3  2  4  1 10] , action: 4
# joint Message: [(2, 3), (1, 9)]
# +-----------------------+
# |D: |F: | : | : | : |F: |
# | : | : : : | : | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (1,1), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,6), Collided: False
# Passenger1: Location: Taxi2, Destination: (5, 10)
# Passenger2: Location: Taxi1, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [4, 3]
# ---------------------------ROUND 11---------------------------------
# taxi_0 obs:
#  [ 1  1  1  6  6  5  5 10  0  0  4  3  2  3  1  9] , action: 1
# taxi_1 obs:
#  [ 1  6  1  6  6  5  5 10  0  0  4  3  2  3  1  9] , action: 2
# joint Message: [(2, 2), (1, 8)]
# +-----------------------+
# |D: |F: | : | : | : |F: |
# | : | : : : | : | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,1), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,7), Collided: False
# Passenger1: Location: Taxi2, Destination: (5, 10)
# Passenger2: Location: Taxi1, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [4, 3]
# ---------------------------ROUND 12---------------------------------
# taxi_0 obs:
#  [ 0  1  1  6  6  5  5 10  0  0  4  3  2  2  1  8] , action: 3
# taxi_1 obs:
#  [ 1  7  1  6  6  5  5 10  0  0  4  3  2  2  1  8] , action: 0
# joint Message: [(2, 1), (1, 7)]
# +-----------------------+
# |D: |F: | : | : | : |F: |
# | : | : : : | : | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,7), Collided: False
# Passenger1: Location: Taxi2, Destination: (5, 10)
# Passenger2: Location: Taxi1, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [4, 3]
# ---------------------------ROUND 13---------------------------------
# taxi_0 obs:
#  [ 0  0  1  6  6  5  5 10  0  0  4  3  2  1  1  7] , action: 6
# taxi_1 obs:
#  [ 2  7  1  6  6  5  5 10  0  0  4  3  2  1  1  7] , action: 2
# joint Message: [(2, 0), (1, 6)]
# +-----------------------+
# |_: |F: | : | : | : |F: |
# | : | : : : | : | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,8), Collided: False
# Passenger1: Location: Taxi2, Destination: (5, 10)
# Passenger2: Location: Arrived!, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [4, 1]
# ---------------------------ROUND 14---------------------------------
# no plan found for passenger 0
# no available plan was found
# taxi_0 obs:
#  [ 0  0  1  6  6  5  5 10  0  0  4  1  2  0  1  6] , action: 5
# taxi_1 obs:
#  [ 2  8  1  6  6  5  5 10  0  0  4  1  2  0  1  6] , action: 2
# joint Message: [(2, 0), (1, 5)]
# +-----------------------+
# |_: |F: | : | : | : |F: |
# | : | : : : | : | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Passenger1: Location: Taxi2, Destination: (5, 10)
# Passenger2: Location: Arrived!, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [4, 1]
# ---------------------------ROUND 15---------------------------------
# no plan found for passenger 0
# no available plan was found
# taxi_0 obs:
#  [ 0  0  1  6  6  5  5 10  0  0  4  1  2  0  1  5] , action: 5
# taxi_1 obs:
#  [ 2  9  1  6  6  5  5 10  0  0  4  1  2  0  1  5] , action: 2
# joint Message: [(2, 0), (1, 4)]
# +-----------------------+
# |_: |F: | : | : | : |F: |
# | : | : : : | : | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,10), Collided: False
# Passenger1: Location: Taxi2, Destination: (5, 10)
# Passenger2: Location: Arrived!, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [4, 1]
# +-----------------------+
# |_: |F: | : | : | : |F: |
# | : | : : : | : | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,10), Collided: False
# Passenger1: Location: Taxi2, Destination: (5, 10)
# Passenger2: Location: Arrived!, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [4, 1]
# Thats all - part 1

# %% [markdown]
# In the above example, we can see that both agents intended to go to the same location to pick up the same passenger. The first agent to arrive at the passenger's location got to pick him up, while the other wasted effort and received nothing in return.

# %% [markdown]
# ## Creating the Communication Infrastructer
#
# In our solution we modeld the world as a POMDP usign the tuple $\langle S, s_{0}, A, P, R, \gamma, \Omega, O \rangle$ where
#
# - $S$ is the set of all possible environment configurations,
# - $s_{0}$ the initial state,
# - $A$ the action space, is the list of actions the taxi agents can execute within the environment **including communication**,
# - $P$ is a state transition probability function,
# - $R$ is the reward function,
# - $\gamma \in [0,1]$ is a discount factor,
# - $\Omega$ is a set of observations where the **information form the observations also becomes an observation**, and
# - $O$ is an observation function
#
#
# ## MAC-COM - simple to use:
#
# <img src='images/MAC-com.jpg' width="800" height="800">
#
#
# ##### All you need for using com module:
#     - Implement Agent_com class (inherit from Agent_com)
#         for this agent:
#         1 - make sure to implement set_data_func -  decides what data to transmit whenever it called
#         2 - recieve_func - implement yours to decide what to do with a recieved data
#             (defualt is the union_func that add the message data to the observation)
#      - implement COM module (network) - and use COM-controller
#         3 - defualt is all recieve the last messages as Joint_Message
# <img src='images/MAC_COM_pic.jpg' width="500" height="500">

# %%
environment = build_multi_env(env)
#
print('EnvironmentWrapper created')

"""
in order to use com module: 
    - implement Agent_com class (inherit from Agent_com
    - make sure to implement set_data_func - that decides what is the data that the agent will transmit whenever it called
    - u can implement your recieve_func - that decides what to do with a recieved data
        defualt is the union_func that add the message data to the observation 
"""

class Heading_message_agent(Agent_Com):

    def __init__(self, decision_maker , sensor_function =None, message_filter = None, AgentName = None, bandW = math.inf, union_recieve = True):
        super().__init__(decision_maker , sensor_function, message_filter, AgentName, bandW, union_recieve)
        self.last_action = None

    def set_data_func(self, obs):
        data = (self.last_action)
        return data

    # todo - implement your recive_func (defualt is union with obs)
    # def set_recive_func(self, obs, message):
    #     pass

    # saves last action of the agent - not necessary for com module
    def set_last_action(self, action):
        self.last_action = action

# after having our com-agent class we can set our env agents into a dicentralized_agents dict with a Random DM
env_agents = environment.get_env_agents()
decentralized_agents = {agent_name: Heading_message_agent(RandomDecisionMaker(env.action_space) ,AgentName=agent_name)             # Agent(LearningDecisionMaker(env.action_space))  # can use diffrent DM
                        for agent_name in env_agents}


"""
Simple use of communication network - 
    - build one using COM_net() - defualt architecture is - all masseges sent to all other agents
            *U can use more options - see at COM_net() class doc.
"""
com = COM_net()
""" 
    - initailze our new controller (DecentralizedComController) - using our env, our agents and our com module
        - this controller will perform all joint action and message delieveries at any time-step
"""
controller = DecentralizedComController(environment, decentralized_agents, com)
"""
activate 
"""
controller.run(render=True, max_iteration=3)
# Out:
# EnvironmentWrapper created
# ---------------------------ROUND 1---------------------------------
# taxi_0 obs:
#  MultiDiscrete([ 7 12  7 12  7 12  7 12  7 12  5  5]) , action: 3
# taxi_1 obs:
#  MultiDiscrete([ 7 12  7 12  7 12  7 12  7 12  5  5]) , action: 2
# joint Message: [3, 2]
# +-----------------------+
# |_: |F: | : | : | : |F: |
# | : | : : : | : | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,11), Collided: False
# Passenger1: Location: Taxi2, Destination: (5, 10)
# Passenger2: Location: Arrived!, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [4, 1]
# ---------------------------ROUND 2---------------------------------
# taxi_0 obs:
#  [ 0  0  1  6  6  5  5 10  0  0  4  1  3  2] , action: 5
# taxi_1 obs:
#  [ 2 11  1  6  6  5  5 10  0  0  4  1  3  2] , action: 0
# joint Message: [5, 0]
# +-----------------------+
# |_: |F: | : | : | : |F: |
# | : | : : : | : | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (3,11), Collided: False
# Passenger1: Location: Taxi2, Destination: (5, 10)
# Passenger2: Location: Arrived!, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [4, 1]
# ---------------------------ROUND 3---------------------------------
# taxi_0 obs:
#  [ 0  0  1  6  6  5  5 10  0  0  4  1  5  0] , action: 2
# taxi_1 obs:
#  [ 3 11  1  6  6  5  5 10  0  0  4  1  5  0] , action: 6
# joint Message: [2, 6]
# +-----------------------+
# | :_|F: | : | : | : |F: |
# | : | : : : | : | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,1), Collided: False
# Taxi1-RED: Fuel: inf, Location: (3,11), Collided: False
# Passenger1: Location: Taxi2, Destination: (5, 10)
# Passenger2: Location: Arrived!, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [4, 1]
# +-----------------------+
# | :_|F: | : | : | : |F: |
# | : | : : : | : | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : :D: |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,1), Collided: False
# Taxi1-RED: Fuel: inf, Location: (3,11), Collided: False
# Passenger1: Location: Taxi2, Destination: (5, 10)
# Passenger2: Location: Arrived!, Destination: (0, 0)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [4, 1]

# %% [markdown]
# ## Types of Communication
#
# When it comes to communication, we may split it into two categories:
#
# - **Explicit communication** – A direct, deliberate form of communication, where there is a clear associated intent for the transmitted information to be received by another agent or system over an established channel.
#
# <img src='https://zanzidigital.co.uk/wp-content/uploads/2017/11/chatbot-image.jpg' width=700/>
#
#
# - **Implicit communication** – Information is inferred, meaning This form of communication involves an action (or practical behaviour) representing as a message in itself, rather than a message being conveyed through language or codified gestures (such as a thumbs-up or a head nod).
# <img src='https://www.robocup.org/system/leagues/images/000/000/001/list/soccer.png?1461148054' width=800/>
#
# In the multiTaxi scenario, for example, implicit communication might take the form of the initial route each taxi takes (assuming that all agents are aware of each other's movements), but explicit communication can take the form of each taxi stating which passenger they want to pick up. There are other more explicit and implicit communication methods that might be used.
#
# The agents in the last example employ **explicit communication** to relay a message to the other agents. They specify which passenger they are going to in the message. We have completed the first three steps of the communication cycle, which means that the agents still do not know how to use communication to their benefit, nor do they know when to communicate.
#
# In the following example - we use a simple rule-based (grounded communication rule) in order to 'wisely-use' other taxis messages: if someones has a shortest path to handle your target passenger, switch to other passenger.

# %%
"""
part 2 - 
com_emerge_use of message for getting better + introducing com-module
"""
from src.decision_makers.planners.MA_com_planner import Astar_message_DM



"""
Builds Multi_taxi env
"""
m = MAP
env = MultiTaxiEnv(num_taxis=3, num_passengers=5, domain_map=m, observation_type='symbolic',rewards_table=TAXI_pickup_dropoff_REWARDS ,option_to_stand_by=True)
obs = env.reset()

environment = build_multi_env(env)
#
print('EnvironmentWrapper created')

# making agent class that communicates and heads towards 1 passenger (pickup->dropoff)
"""
in order to use com module: 
    - implement Agent_com class (inherit from Agent_com
    - make sure to implement set_data_func - that decides what is the data that the agent will transmit whenever it called
    - u can implement your recieve_func - that decides what to do with a recieved data
        defualt is the union_func that add the message data to the observation 
"""

class Heading_message_agent(Agent_Com):

    def __init__(self, decision_maker : Astar_message_DM , sensor_function =None, message_filter = None, AgentName = None, bandW = math.inf, union_recieve = False):
        super().__init__(decision_maker , sensor_function, message_filter, AgentName, bandW, union_recieve)
        self.last_action = None
        self.last_message = None

    def set_data_func(self, obs):
        data = (self.decision_maker.taking_passenger,len(self.decision_maker.active_plan))
        return data

    # implement our recive_func
    def set_recive_func(self, obs, message):
        self.last_message = message
        self.decision_maker.save_last_message(message)
        # self.decision_maker.updateplan_message(message)

    # saves last action of the agent - not necessary for com module
    def set_last_action(self, action):
        self.last_action = action
#
#


# after having our com-Astar-agents class we can set our env agents into a dicentralized_agents dict
env_agents = environment.get_env_agents()
decentralized_agents = {agent_name: Heading_message_agent(Astar_message_DM(env ,single_plan=True, Taxi_index=int(agent_name[-1]), domain_map=m) ,AgentName=agent_name)             # Agent(LearningDecisionMaker(env.action_space))  # can use diffrent DM
                        for agent_name in env_agents}


"""
Simple use of communication network - 
    - build one using COM_net() - defualt architecture is - all masseges sent to all other agents
            *U can use more options - see at COM_net() class doc.
"""
com = COM_net()
""" 
    - initailze our new controller (DecentralizedComController) - using our env, our agents and our com module
        - this controller will perform all joint action and message delieveries at any time-step
"""
controller = DecentralizedComController(environment, decentralized_agents, com)
"""
activate 
"""
#communicate first
controller.send_recieve()

#run (communication inside after each time_click)
controller.run(render=True, max_iteration=20,reset=True)
print("Thats all - part 2")
# Out:
# EnvironmentWrapper created
# send_recieve - Joint message: [(None, 0), (None, 0), (None, 0)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | :P| : : : | : | : | : |
# | : :D:_:D: : : : : : :D|
# | : :_: : : | : : :P: : |
# |_: : : : : | : :P: :D: |
# | : : : : : : : : : :P: |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,3), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (3,2), Collided: False
# Passenger1: Location: (1, 1), Destination: (2, 4)
# Passenger2: Location: (3, 9), Destination: (6, 3)
# Passenger3: Location: (4, 8), Destination: (2, 11)
# Passenger4: Location: (5, 10), Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 2, 2, 2]
# ---------------------------ROUND 1---------------------------------
# Yellow Taxi_0 (re)planning results:
#   # taking Yellow passenger, len. of plan: 10 -> active:['(1,)', '(1,)', '(1,)', '(2,)', '(4,)', '(0,)', '(2,)', '(2,)', '(2,)', '(5,)']
#   # all plans:[('Yellow', 10), ('Red', 23), ('White', 17), ('Green', 14), ('Cyan', 24)]
# Red Taxi_1 (re)planning results:
#   # taking Yellow passenger, len. of plan: 9 -> active:['(3,)', '(3,)', '(1,)', '(4,)', '(0,)', '(2,)', '(2,)', '(2,)', '(5,)']
#   # all plans:[('Yellow', 9), ('Red', 18), ('White', 14), ('Green', 13), ('Cyan', 19)]
# White Taxi_2 (re)planning results:
#   # taking Yellow passenger, len. of plan: 9 -> active:['(1,)', '(3,)', '(1,)', '(4,)', '(0,)', '(2,)', '(2,)', '(2,)', '(5,)']
#   # all plans:[('Yellow', 9), ('Red', 20), ('White', 16), ('Green', 13), ('Cyan', 21)]
# taxi_0 obs:
#  [ 4  0  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  2  2
#   2  2  2] , action: 1
# taxi_1 obs:
#  [ 2  3  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  2  2
#   2  2  2] , action: 3
# taxi_2 obs:
#  [ 3  2  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  2  2
#   2  2  2] , action: 1
# joint Message: [(1, 9), (1, 8), (1, 8)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | :P| : : : | : | : | : |
# | : :D: :D: : : : : : :D|
# |_: : : : : | : : :P: : |
# | : : : : : | : :P: :D: |
# | : : : : : : : : : :P: |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,2), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,2), Collided: False
# Passenger1: Location: (1, 1), Destination: (2, 4)
# Passenger2: Location: (3, 9), Destination: (6, 3)
# Passenger3: Location: (4, 8), Destination: (2, 11)
# Passenger4: Location: (5, 10), Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 2, 2, 2]
# ---------------------------ROUND 2---------------------------------
# changing plan acording to message
# Yellow Taxi_0 (re)planning results:
#   # taking Green passenger, len. of plan: 15 -> active:['(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(0,)', '(0,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(4,)', '(1,)', '(8,)']
#   # all plans:[('Red', 22), ('White', 18), ('Green', 15), ('Cyan', 23)]
# taxi_0 obs:
#  [ 3  0  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  2  2
#   2  2  2] , action: 2
# taxi_1 obs:
#  [ 2  2  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  2  2
#   2  2  2] , action: 3
# taxi_2 obs:
#  [ 2  2  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  2  2
#   2  2  2] , action: 3
# joint Message: [(4, 14), (1, 7), (1, 7)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | :P| : : : | : | : | : |
# | :_:D: :D: : : : : : :D|
# | :_: : : : | : : :P: : |
# | : : : : : | : :P: :D: |
# | : : : : : : : : : :P: |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,1), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,1), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,1), Collided: False
# Passenger1: Location: (1, 1), Destination: (2, 4)
# Passenger2: Location: (3, 9), Destination: (6, 3)
# Passenger3: Location: (4, 8), Destination: (2, 11)
# Passenger4: Location: (5, 10), Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 2, 2, 2]
# ---------------------------ROUND 3---------------------------------
# taxi_0 obs:
#  [ 3  1  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  2  2
#   2  2  2] , action: 2
# taxi_1 obs:
#  [ 2  1  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  2  2
#   2  2  2] , action: 1
# taxi_2 obs:
#  [ 2  1  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  2  2
#   2  2  2] , action: 1
# joint Message: [(4, 13), (1, 6), (1, 6)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | :P| : : : | : | : | : |
# | : :D: :D: : : : : : :D|
# | : :_: : : | : : :P: : |
# | : : : : : | : :P: :D: |
# | : : : : : : : : : :P: |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,2), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,1), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,1), Collided: False
# Passenger1: Location: (1, 1), Destination: (2, 4)
# Passenger2: Location: (3, 9), Destination: (6, 3)
# Passenger3: Location: (4, 8), Destination: (2, 11)
# Passenger4: Location: (5, 10), Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 2, 2, 2]
# ---------------------------ROUND 4---------------------------------
# taxi_0 obs:
#  [ 3  2  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  2  2
#   2  2  2] , action: 2
# taxi_1 obs:
#  [ 1  1  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  2  2
#   2  2  2] , action: 4
# taxi_2 obs:
#  [ 1  1  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  2  2
#   2  2  2] , action: 4
# joint Message: [(4, 12), (1, 5), (1, 5)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | : | : : : | : | : | : |
# | : :D: :D: : : : : : :D|
# | : : :_: : | : : :P: : |
# | : : : : : | : :P: :D: |
# | : : : : : : : : : :P: |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,3), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,1), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,1), Collided: False
# Passenger1: Location: Taxi3, Destination: (2, 4)
# Passenger2: Location: (3, 9), Destination: (6, 3)
# Passenger3: Location: (4, 8), Destination: (2, 11)
# Passenger4: Location: (5, 10), Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [5, 2, 2, 2, 2]
# ---------------------------ROUND 5---------------------------------
# taxi_0 obs:
#  [ 3  3  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  5  2
#   2  2  2] , action: 2
# taxi_1 obs:
#  [ 1  1  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  5  2
#   2  2  2] , action: 0
# taxi_2 obs:
#  [ 1  1  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  5  2
#   2  2  2] , action: 0
# joint Message: [(4, 11), (1, 4), (1, 4)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | : | : : : | : | : | : |
# | : :D: :D: : : : : : :D|
# | : : : :_: | : : :P: : |
# | : : : : : | : :P: :D: |
# | : : : : : : : : : :P: |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,4), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,1), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,1), Collided: False
# Passenger1: Location: Taxi3, Destination: (2, 4)
# Passenger2: Location: (3, 9), Destination: (6, 3)
# Passenger3: Location: (4, 8), Destination: (2, 11)
# Passenger4: Location: (5, 10), Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [5, 2, 2, 2, 2]
# ---------------------------ROUND 6---------------------------------
# taxi_0 obs:
#  [ 3  4  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  5  2
#   2  2  2] , action: 2
# taxi_1 obs:
#  [ 2  1  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  5  2
#   2  2  2] , action: 2
# taxi_2 obs:
#  [ 2  1  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  5  2
#   2  2  2] , action: 2
# joint Message: [(4, 10), (1, 3), (1, 3)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | : | : : : | : | : | : |
# | : :D: :D: : : : : : :D|
# | : : : : :_| : : :P: : |
# | : : : : : | : :P: :D: |
# | : : : : : : : : : :P: |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,2), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,2), Collided: False
# Passenger1: Location: Taxi3, Destination: (2, 4)
# Passenger2: Location: (3, 9), Destination: (6, 3)
# Passenger3: Location: (4, 8), Destination: (2, 11)
# Passenger4: Location: (5, 10), Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [5, 2, 2, 2, 2]
# ---------------------------ROUND 7---------------------------------
# taxi_0 obs:
#  [ 3  5  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  5  2
#   2  2  2] , action: 0
# taxi_1 obs:
#  [ 2  2  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  5  2
#   2  2  2] , action: 2
# taxi_2 obs:
#  [ 2  2  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  5  2
#   2  2  2] , action: 2
# joint Message: [(4, 9), (1, 2), (1, 2)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | : | : : : | : | : | : |
# | : :D: :D: : : : : : :D|
# | : : : : : | : : :P: : |
# | : : : : :_| : :P: :D: |
# | : : : : : : : : : :P: |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,3), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,3), Collided: False
# Passenger1: Location: Taxi3, Destination: (2, 4)
# Passenger2: Location: (3, 9), Destination: (6, 3)
# Passenger3: Location: (4, 8), Destination: (2, 11)
# Passenger4: Location: (5, 10), Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [5, 2, 2, 2, 2]
# ---------------------------ROUND 8---------------------------------
# taxi_0 obs:
#  [ 4  5  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  5  2
#   2  2  2] , action: 0
# taxi_1 obs:
#  [ 2  3  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  5  2
#   2  2  2] , action: 2
# taxi_2 obs:
#  [ 2  3  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  5  2
#   2  2  2] , action: 2
# joint Message: [(4, 8), (1, 1), (1, 1)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | : | : : : | : | : | : |
# | : :D: :D: : : : : : :D|
# | : : : : : | : : :P: : |
# | : : : : : | : :P: :D: |
# | : : : : :_: : : : :P: |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,4), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,4), Collided: False
# Passenger1: Location: Taxi3, Destination: (2, 4)
# Passenger2: Location: (3, 9), Destination: (6, 3)
# Passenger3: Location: (4, 8), Destination: (2, 11)
# Passenger4: Location: (5, 10), Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [5, 2, 2, 2, 2]
# ---------------------------ROUND 9---------------------------------
# taxi_0 obs:
#  [ 5  5  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  5  2
#   2  2  2] , action: 2
# taxi_1 obs:
#  [ 2  4  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  5  2
#   2  2  2] , action: 5
# taxi_2 obs:
#  [ 2  4  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  5  2
#   2  2  2] , action: 5
# joint Message: [(4, 7), (1, 0), (1, 0)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | : | : : : | : | : | : |
# | : :D: :_: : : : : : :D|
# | : : : : : | : : :P: : |
# | : : : : : | : :P: :D: |
# | : : : : : :_: : : :P: |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,6), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,4), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,4), Collided: False
# Passenger1: Location: Arrived!, Destination: (2, 4)
# Passenger2: Location: (3, 9), Destination: (6, 3)
# Passenger3: Location: (4, 8), Destination: (2, 11)
# Passenger4: Location: (5, 10), Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [1, 2, 2, 2, 2]
# ---------------------------ROUND 10---------------------------------
# Red Taxi_1 (re)planning results:
#   # taking Green passenger, len. of plan: 12 -> active:['(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(0,)', '(0,)', '(0,)', '(4,)', '(1,)', '(8,)']
#   # all plans:[('Red', 17), ('White', 13), ('Green', 12), ('Cyan', 18)]
# changing plan acording to message
# Red Taxi_1 (re)planning results:
#   # taking White passenger, len. of plan: 13 -> active:['(2,)', '(2,)', '(2,)', '(2,)', '(0,)', '(0,)', '(4,)', '(1,)', '(1,)', '(2,)', '(2,)', '(2,)', '(7,)']
#   # all plans:[('Red', 17), ('White', 13), ('Cyan', 18)]
# White Taxi_2 (re)planning results:
#   # taking Green passenger, len. of plan: 12 -> active:['(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(0,)', '(0,)', '(0,)', '(4,)', '(1,)', '(8,)']
#   # all plans:[('Red', 17), ('White', 13), ('Green', 12), ('Cyan', 18)]
# changing plan acording to message
# White Taxi_2 (re)planning results:
#   # taking White passenger, len. of plan: 13 -> active:['(2,)', '(2,)', '(2,)', '(2,)', '(0,)', '(0,)', '(4,)', '(1,)', '(1,)', '(2,)', '(2,)', '(2,)', '(7,)']
#   # all plans:[('Red', 17), ('White', 13), ('Cyan', 18)]
# taxi_0 obs:
#  [ 5  6  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  2  2] , action: 2
# taxi_1 obs:
#  [ 2  4  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  2  2] , action: 2
# taxi_2 obs:
#  [ 2  4  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  2  2] , action: 2
# joint Message: [(4, 6), (3, 12), (3, 12)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | : | : : : | : | : | : |
# | : :D: : :_: : : : : :D|
# | : : : : : | : : :P: : |
# | : : : : : | : :P: :D: |
# | : : : : : : :_: : :P: |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,7), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,5), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,5), Collided: False
# Passenger1: Location: Arrived!, Destination: (2, 4)
# Passenger2: Location: (3, 9), Destination: (6, 3)
# Passenger3: Location: (4, 8), Destination: (2, 11)
# Passenger4: Location: (5, 10), Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [1, 2, 2, 2, 2]
# ---------------------------ROUND 11---------------------------------
# taxi_0 obs:
#  [ 5  7  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  2  2] , action: 2
# taxi_1 obs:
#  [ 2  5  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  2  2] , action: 2
# taxi_2 obs:
#  [ 2  5  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  2  2] , action: 2
# joint Message: [(4, 5), (3, 11), (3, 11)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | : | : : : | : | : | : |
# | : :D: : : :_: : : : :D|
# | : : : : : | : : :P: : |
# | : : : : : | : :P: :D: |
# | : : : : : : : :_: :P: |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,8), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,6), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,6), Collided: False
# Passenger1: Location: Arrived!, Destination: (2, 4)
# Passenger2: Location: (3, 9), Destination: (6, 3)
# Passenger3: Location: (4, 8), Destination: (2, 11)
# Passenger4: Location: (5, 10), Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [1, 2, 2, 2, 2]
# ---------------------------ROUND 12---------------------------------
# taxi_0 obs:
#  [ 5  8  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  2  2] , action: 2
# taxi_1 obs:
#  [ 2  6  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  2  2] , action: 2
# taxi_2 obs:
#  [ 2  6  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  2  2] , action: 2
# joint Message: [(4, 4), (3, 10), (3, 10)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | : | : : : | : | : | : |
# | : :D: : : : :_: : : :D|
# | : : : : : | : : :P: : |
# | : : : : : | : :P: :D: |
# | : : : : : : : : :_:P: |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,9), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,7), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,7), Collided: False
# Passenger1: Location: Arrived!, Destination: (2, 4)
# Passenger2: Location: (3, 9), Destination: (6, 3)
# Passenger3: Location: (4, 8), Destination: (2, 11)
# Passenger4: Location: (5, 10), Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [1, 2, 2, 2, 2]
# ---------------------------ROUND 13---------------------------------
# taxi_0 obs:
#  [ 5  9  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  2  2] , action: 2
# taxi_1 obs:
#  [ 2  7  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  2  2] , action: 2
# taxi_2 obs:
#  [ 2  7  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  2  2] , action: 2
# joint Message: [(4, 3), (3, 9), (3, 9)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | : | : : : | : | : | : |
# | : :D: : : : : :_: : :D|
# | : : : : : | : : :P: : |
# | : : : : : | : :P: :D: |
# | : : : : : : : : : :P: |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,10), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,8), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,8), Collided: False
# Passenger1: Location: Arrived!, Destination: (2, 4)
# Passenger2: Location: (3, 9), Destination: (6, 3)
# Passenger3: Location: (4, 8), Destination: (2, 11)
# Passenger4: Location: (5, 10), Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [1, 2, 2, 2, 2]
# ---------------------------ROUND 14---------------------------------
# taxi_0 obs:
#  [ 5 10  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  2  2] , action: 4
# taxi_1 obs:
#  [ 2  8  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  2  2] , action: 0
# taxi_2 obs:
#  [ 2  8  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  2  2] , action: 0
# joint Message: [(4, 2), (3, 8), (3, 8)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | : | : : : | : | : | : |
# | : :D: : : : : : : : :D|
# | : : : : : | : :_:P: : |
# | : : : : : | : :P: :D: |
# | : : : : : : : : : : : |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,10), Collided: False
# Taxi1-RED: Fuel: inf, Location: (3,8), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (3,8), Collided: False
# Passenger1: Location: Arrived!, Destination: (2, 4)
# Passenger2: Location: (3, 9), Destination: (6, 3)
# Passenger3: Location: (4, 8), Destination: (2, 11)
# Passenger4: Location: Taxi1, Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [1, 2, 2, 3, 2]
# ---------------------------ROUND 15---------------------------------
# taxi_0 obs:
#  [ 5 10  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  3  2] , action: 1
# taxi_1 obs:
#  [ 3  8  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  3  2] , action: 0
# taxi_2 obs:
#  [ 3  8  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  3  2] , action: 0
# joint Message: [(4, 1), (3, 7), (3, 7)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | : | : : : | : | : | : |
# | : :D: : : : : : : : :D|
# | : : : : : | : : :P: : |
# | : : : : : | : :P: :D: |
# | : : : : : : : : : : : |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,10), Collided: False
# Taxi1-RED: Fuel: inf, Location: (4,8), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (4,8), Collided: False
# Passenger1: Location: Arrived!, Destination: (2, 4)
# Passenger2: Location: (3, 9), Destination: (6, 3)
# Passenger3: Location: (4, 8), Destination: (2, 11)
# Passenger4: Location: Taxi1, Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [1, 2, 2, 3, 2]
# ---------------------------ROUND 16---------------------------------
# taxi_0 obs:
#  [ 4 10  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  3  2] , action: 8
# taxi_1 obs:
#  [ 4  8  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  3  2] , action: 4
# taxi_2 obs:
#  [ 4  8  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   2  3  2] , action: 4
# joint Message: [(4, 0), (3, 6), (3, 6)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | : | : : : | : | : | : |
# | : :D: : : : : : : : :D|
# | : : : : : | : : :P: : |
# | : : : : : | : : : :_: |
# | : : : : : : : : : : : |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,10), Collided: False
# Taxi1-RED: Fuel: inf, Location: (4,8), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (4,8), Collided: False
# Passenger1: Location: Arrived!, Destination: (2, 4)
# Passenger2: Location: (3, 9), Destination: (6, 3)
# Passenger3: Location: Taxi2, Destination: (2, 11)
# Passenger4: Location: Arrived!, Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [1, 2, 4, 1, 2]
# ---------------------------ROUND 17---------------------------------
# agent_0: no available plan found for passenger 2
# Yellow Taxi_0 (re)planning results:
#   # taking Red passenger, len. of plan: 13 -> active:['(1,)', '(3,)', '(4,)', '(3,)', '(3,)', '(3,)', '(0,)', '(0,)', '(3,)', '(3,)', '(3,)', '(0,)', '(6,)']
#   # all plans:[('Red', 13), ('Cyan', 16)]
# taxi_0 obs:
#  [ 4 10  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   4  1  2] , action: 1
# taxi_1 obs:
#  [ 4  8  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   4  1  2] , action: 1
# taxi_2 obs:
#  [ 4  8  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   4  1  2] , action: 1
# joint Message: [(2, 12), (3, 5), (3, 5)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | : | : : : | : | : | : |
# | : :D: : : : : : : : :D|
# | : : : : : | : : :P:_: |
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,10), Collided: False
# Taxi1-RED: Fuel: inf, Location: (3,8), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (3,8), Collided: False
# Passenger1: Location: Arrived!, Destination: (2, 4)
# Passenger2: Location: (3, 9), Destination: (6, 3)
# Passenger3: Location: Taxi2, Destination: (2, 11)
# Passenger4: Location: Arrived!, Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [1, 2, 4, 1, 2]
# ---------------------------ROUND 18---------------------------------
# taxi_0 obs:
#  [ 3 10  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   4  1  2] , action: 3
# taxi_1 obs:
#  [ 3  8  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   4  1  2] , action: 1
# taxi_2 obs:
#  [ 3  8  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   4  1  2] , action: 1
# joint Message: [(2, 11), (3, 4), (3, 4)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | : | : : : | : | : | : |
# | : :D: : : : : : : : :D|
# | : : : : : | : : :P: : |
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,9), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,8), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,8), Collided: False
# Passenger1: Location: Arrived!, Destination: (2, 4)
# Passenger2: Location: (3, 9), Destination: (6, 3)
# Passenger3: Location: Taxi2, Destination: (2, 11)
# Passenger4: Location: Arrived!, Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [1, 2, 4, 1, 2]
# ---------------------------ROUND 19---------------------------------
# taxi_0 obs:
#  [ 3  9  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   4  1  2] , action: 4
# taxi_1 obs:
#  [ 2  8  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   4  1  2] , action: 2
# taxi_2 obs:
#  [ 2  8  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  2
#   4  1  2] , action: 2
# joint Message: [(2, 10), (3, 3), (3, 3)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | : | : : : | : | : | : |
# | : :D: : : : : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,9), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,9), Collided: False
# Passenger1: Location: Arrived!, Destination: (2, 4)
# Passenger2: Location: Taxi1, Destination: (6, 3)
# Passenger3: Location: Taxi2, Destination: (2, 11)
# Passenger4: Location: Arrived!, Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [1, 3, 4, 1, 2]
# ---------------------------ROUND 20---------------------------------
# taxi_0 obs:
#  [ 3  9  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  3
#   4  1  2] , action: 3
# taxi_1 obs:
#  [ 2  9  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  3
#   4  1  2] , action: 2
# taxi_2 obs:
#  [ 2  9  1  1  3  9  4  8  5 10  0  9  2  4  6  3  2 11  4 10  2  2  1  3
#   4  1  2] , action: 2
# joint Message: [(2, 9), (3, 2), (3, 2)]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | : | : : : | : | : | : |
# | : :D: : : : : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,8), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,10), Collided: False
# Passenger1: Location: Arrived!, Destination: (2, 4)
# Passenger2: Location: Taxi1, Destination: (6, 3)
# Passenger3: Location: Taxi2, Destination: (2, 11)
# Passenger4: Location: Arrived!, Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [1, 3, 4, 1, 2]
# +-----------------------+
# | : |F: | : | : | :P|F: |
# | : | : : : | : | : | : |
# | : :D: : : : : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G|D| | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,8), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,10), Collided: False
# Passenger1: Location: Arrived!, Destination: (2, 4)
# Passenger2: Location: Taxi1, Destination: (6, 3)
# Passenger3: Location: Taxi2, Destination: (2, 11)
# Passenger4: Location: Arrived!, Destination: (4, 10)
# Passenger5: Location: (0, 9), Destination: (2, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [1, 3, 4, 1, 2]
# Thats all - part 2

# %% [markdown]
# ## Using Communication to Our Advantage
#
# Having established that the agents can send and receive messages, they must now learn how to utilize them and what to do with them. They are pointless if they do not behave in line with the massages. In emergent communication we can learn how to do it autonomously

# %%
"""
part 2.2 - 
agents learn now - hierarchical_tasks
"""

# import hierarchical_tasks multi taxi env
from src.environments.hirarchical_Wrapper import Multi_Taxi_Task_Wrapper
from src.decision_makers.planners.Com_High_level_Planner import Astar_message_highlevel_DM
"""
Builds Multi_taxi env
"""
m = MAP
env = MultiTaxiEnv(num_taxis=3, num_passengers=5, domain_map=m, observation_type='symbolic',rewards_table=TAXI_pickup_dropoff_REWARDS ,option_to_stand_by=True)

obs = env.reset()

environment = build_multi_env(env)

environment =  Multi_Taxi_Task_Wrapper(environment)
#
print('EnvironmentWrapper Multi_Taxi_Task_Wrapper created')

# making agent class that communicates and heads towards 1 passenger (pickup->dropoff)

class Heading_message_agent(Agent_Com):

    def __init__(self, decision_maker : Astar_message_highlevel_DM , sensor_function =None, message_filter = None, AgentName = None, bandW = math.inf, union_recieve = False):
        super().__init__(decision_maker , sensor_function, message_filter, AgentName, bandW, union_recieve)
        self.last_action = None
        self.last_message = None

    def set_data_func(self, obs):
        data = (self.decision_maker.taking_passenger,len(self.decision_maker.active_plan))
        return data

    # implement our recive_func
    def set_recive_func(self, obs, message):
        self.last_message = message
        self.decision_maker.save_last_message(message)
        # self.decision_maker.updateplan_message(message)

    # saves last action of the agent - not necessary for com module
    def set_last_action(self, action):
        self.last_action = action


# run again - high-level
env_agents = environment.get_env_agents()
decentralized_agents = {agent_name: Heading_message_agent(Astar_message_highlevel_DM(env ,single_plan=True, Taxi_index=int(agent_name[-1]), domain_map=m) ,AgentName=agent_name)             # Agent(LearningDecisionMaker(env.action_space))  # can use diffrent DM
                        for agent_name in env_agents}

controller = DecentralizedComController(environment, decentralized_agents, com)
"""
activate 
"""
#communicate first
controller.send_recieve()

#run (communication inside after each time_click)
controller.run(render=True, max_iteration=250,reset=True)

# SHOW REWARDS
reward = controller.total_rewards
totals = {}
for r in reward[0]:
    totals[r] = 0
total=0
for r in reward:
    for key, value in r.items():
        totals[key]+=value
        total+=value
print(f"----------------------------------\n total reward of all agents: {total}, {totals} \n----------------------------------")
print("Thats all - part 2.2")
# Out:
# EnvironmentWrapper Multi_Taxi_Task_Wrapper created
# send_recieve - Joint message: [(None, 0), (None, 0), (None, 0)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : |D: : :D| : | : | : |
# | : :P: : : : : :D: : : |
# | : :D: : :_| : : : : :D|
# | : : : : : | : :P: :P: |
# | :_: : : : : : : : : : |
# |P| :G| |_| :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,1), Collided: False
# Taxi1-RED: Fuel: inf, Location: (6,4), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (3,5), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: (4, 8), Destination: (3, 2)
# Passenger3: Location: (2, 2), Destination: (1, 2)
# Passenger4: Location: (0, 10), Destination: (1, 5)
# Passenger5: Location: (4, 10), Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 2, 2, 2]
# ---------------------------ROUND 1---------------------------------
# Yellow Taxi_0 (re)planning results:
#   # taking White passenger, len. of plan: 7 -> active:['(1,)', '(1,)', '(1,)', '(2,)', '(4,)', '(1,)', '(7,)']
#   # all plans:[('Yellow', 18), ('Red', 19), ('White', 7), ('Green', 24), ('Cyan', 16)]
# Red Taxi_1 (re)planning results:
#   # taking White passenger, len. of plan: 9 -> active:['(1,)', '(1,)', '(1,)', '(1,)', '(3,)', '(3,)', '(4,)', '(1,)', '(7,)']
#   # all plans:[('Yellow', 22), ('Red', 17), ('White', 9), ('Green', 22), ('Cyan', 14)]
# White Taxi_2 (re)planning results:
#   # taking White passenger, len. of plan: 7 -> active:['(1,)', '(3,)', '(3,)', '(3,)', '(4,)', '(1,)', '(7,)']
#   # all plans:[('Yellow', 24), ('Red', 17), ('White', 7), ('Green', 18), ('Cyan', 14)]
# taxi_0 obs:
#  [ 5  1  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   2  2  2] , action: 3
# taxi_1 obs:
#  [ 6  4  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   2  2  2] , action: 3
# taxi_2 obs:
#  [ 3  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   2  2  2] , action: 3
# joint Message: [(3, 6), (3, 8), (3, 6)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : |D: : :D| : | : | : |
# | : :P: : :_: : :D: : : |
# | : :D: : : | : : : : :D|
# | :_: : : : | : :P: :P: |
# | : : : :_: : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,1), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,4), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,5), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: (4, 8), Destination: (3, 2)
# Passenger3: Location: (2, 2), Destination: (1, 2)
# Passenger4: Location: (0, 10), Destination: (1, 5)
# Passenger5: Location: (4, 10), Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 2, 2, 2]
# ---------------------------ROUND 2---------------------------------
# changing plan acording to message
# Red Taxi_1 (re)planning results:
#   # taking Cyan passenger, len. of plan: 13 -> active:['(2,)', '(2,)', '(1,)', '(2,)', '(2,)', '(2,)', '(2,)', '(4,)', '(1,)', '(1,)', '(3,)', '(3,)', '(9,)']
#   # all plans:[('Yellow', 21), ('Red', 16), ('Green', 21), ('Cyan', 13)]
# taxi_0 obs:
#  [ 4  1  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   2  2  2] , action: 3
# taxi_1 obs:
#  [ 5  4  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   2  2  2] , action: 5
# taxi_2 obs:
#  [ 2  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   2  2  2] , action: 3
# joint Message: [(3, 5), (5, 12), (3, 5)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : |D: : :D| : | : | : |
# | : :P: :_: : : :D: : : |
# | :_:D: : : | : : : : :D|
# | : : : : : | : :P: :P: |
# | : : : : :_: : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,1), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,5), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,4), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: (4, 8), Destination: (3, 2)
# Passenger3: Location: (2, 2), Destination: (1, 2)
# Passenger4: Location: (0, 10), Destination: (1, 5)
# Passenger5: Location: (4, 10), Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 2, 2, 2]
# ---------------------------ROUND 3---------------------------------
# taxi_0 obs:
#  [ 3  1  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   2  2  2] , action: 3
# taxi_1 obs:
#  [ 5  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   2  2  2] , action: 5
# taxi_2 obs:
#  [ 2  4  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   2  2  2] , action: 3
# joint Message: [(3, 4), (5, 11), (3, 4)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : |D: : :D| : | : | : |
# | :_:P:_: : : : :D: : : |
# | : :D: : : | : : : : :D|
# | : : : : : | : :P: :P: |
# | : : : : : :_: : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,1), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,6), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,3), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: (4, 8), Destination: (3, 2)
# Passenger3: Location: (2, 2), Destination: (1, 2)
# Passenger4: Location: (0, 10), Destination: (1, 5)
# Passenger5: Location: (4, 10), Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 2, 2, 2]
# ---------------------------ROUND 4---------------------------------
# taxi_0 obs:
#  [ 2  1  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   2  2  2] , action: 3
# taxi_1 obs:
#  [ 5  6  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   2  2  2] , action: 5
# taxi_2 obs:
#  [ 2  3  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   2  2  2] , action: 3
# joint Message: [(3, 3), (5, 10), (3, 3)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : |D: : :D| : | : | : |
# | : :P: : : : : :D: : : |
# | : :D: : : | : : : : :D|
# | : : : : : |_: :P: :P: |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,2), Collided: False
# Taxi1-RED: Fuel: inf, Location: (4,6), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,2), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: (4, 8), Destination: (3, 2)
# Passenger3: Location: (2, 2), Destination: (1, 2)
# Passenger4: Location: (0, 10), Destination: (1, 5)
# Passenger5: Location: (4, 10), Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 2, 2, 2]
# ---------------------------ROUND 5---------------------------------
# taxi_0 obs:
#  [ 2  2  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   2  2  2] , action: 3
# taxi_1 obs:
#  [ 4  6  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   2  2  2] , action: 5
# taxi_2 obs:
#  [ 2  2  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   2  2  2] , action: 3
# joint Message: [(3, 2), (5, 9), (3, 2)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : |D: : :D| : | : | : |
# | : : : : : : : :D: : : |
# | : :D: : : | : : : : :D|
# | : : : : : | :_:P: :P: |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,2), Collided: False
# Taxi1-RED: Fuel: inf, Location: (4,7), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,2), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: (4, 8), Destination: (3, 2)
# Passenger3: Location: Taxi3, Destination: (1, 2)
# Passenger4: Location: (0, 10), Destination: (1, 5)
# Passenger5: Location: (4, 10), Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 5, 2, 2]
# ---------------------------ROUND 6---------------------------------
# taxi_0 obs:
#  [ 2  2  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   5  2  2] , action: 3
# taxi_1 obs:
#  [ 4  7  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   5  2  2] , action: 5
# taxi_2 obs:
#  [ 2  2  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   5  2  2] , action: 3
# joint Message: [(3, 1), (5, 8), (3, 1)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : |D: : :D| : | : | : |
# | : :_: : : : : :D: : : |
# | : :D: : : | : : : : :D|
# | : : : : : | : :P: :P: |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,2), Collided: False
# Taxi1-RED: Fuel: inf, Location: (4,8), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,2), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: (4, 8), Destination: (3, 2)
# Passenger3: Location: Taxi3, Destination: (1, 2)
# Passenger4: Location: (0, 10), Destination: (1, 5)
# Passenger5: Location: (4, 10), Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 5, 2, 2]
# ---------------------------ROUND 7---------------------------------
# taxi_0 obs:
#  [ 2  2  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   5  2  2] , action: 3
# taxi_1 obs:
#  [ 4  8  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   5  2  2] , action: 5
# taxi_2 obs:
#  [ 1  2  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   5  2  2] , action: 3
# joint Message: [(3, 0), (5, 7), (3, 0)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : |_: : :D| : | : | : |
# | : :_: : : : : :D: : : |
# | : :D: : : | : : : : :D|
# | : : : : : | : :P:_:P: |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,2), Collided: False
# Taxi1-RED: Fuel: inf, Location: (4,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,2), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: (4, 8), Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: (0, 10), Destination: (1, 5)
# Passenger5: Location: (4, 10), Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 1, 2, 2]
# ---------------------------ROUND 8---------------------------------
# Yellow Taxi_0 (re)planning results:
#   # taking Cyan passenger, len. of plan: 16 -> active:['(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(0,)', '(0,)', '(4,)', '(1,)', '(1,)', '(3,)', '(3,)', '(9,)']
#   # all plans:[('Yellow', 22), ('Red', 19), ('Green', 20), ('Cyan', 16)]
# changing plan acording to message
# Yellow Taxi_0 (re)planning results:
#   # taking Red passenger, len. of plan: 19 -> active:['(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(0,)', '(0,)', '(4,)', '(1,)', '(3,)', '(3,)', '(1,)', '(3,)', '(3,)', '(3,)', '(3,)', '(0,)', '(6,)']
#   # all plans:[('Yellow', 22), ('Red', 19), ('Green', 20)]
# White Taxi_2 (re)planning results:
#   # taking Cyan passenger, len. of plan: 17 -> active:['(2,)', '(2,)', '(2,)', '(0,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(0,)', '(0,)', '(4,)', '(1,)', '(1,)', '(3,)', '(3,)', '(9,)']
#   # all plans:[('Yellow', 23), ('Red', 20), ('Green', 21), ('Cyan', 17)]
# changing plan acording to message
# White Taxi_2 (re)planning results:
#   # taking Red passenger, len. of plan: 20 -> active:['(2,)', '(2,)', '(2,)', '(0,)', '(2,)', '(2,)', '(2,)', '(0,)', '(0,)', '(4,)', '(1,)', '(3,)', '(3,)', '(1,)', '(3,)', '(3,)', '(3,)', '(3,)', '(0,)', '(6,)']
#   # all plans:[('Yellow', 23), ('Red', 20), ('Green', 21)]
# taxi_0 obs:
#  [ 2  2  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  2] , action: 2
# taxi_1 obs:
#  [ 4  9  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  2] , action: 5
# taxi_2 obs:
#  [ 1  2  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  2] , action: 2
# joint Message: [(2, 18), (5, 6), (2, 19)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : | :_: :D| : | : | : |
# | : : :_: : : : :D: : : |
# | : :D: : : | : : : : :D|
# | : : : : : | : :P: :P: |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,3), Collided: False
# Taxi1-RED: Fuel: inf, Location: (4,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,3), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: (4, 8), Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: (0, 10), Destination: (1, 5)
# Passenger5: Location: (4, 10), Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 1, 2, 2]
# ---------------------------ROUND 9---------------------------------
# changing plan acording to message
# White Taxi_2 (re)planning results:
#   # taking Cyan passenger, len. of plan: 16 -> active:['(2,)', '(2,)', '(0,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(0,)', '(0,)', '(4,)', '(1,)', '(1,)', '(3,)', '(3,)', '(9,)']
#   # all plans:[('Yellow', 24), ('Green', 20), ('Cyan', 16)]
# taxi_0 obs:
#  [ 2  3  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  2] , action: 2
# taxi_1 obs:
#  [ 4 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  2] , action: 5
# taxi_2 obs:
#  [ 1  3  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  2] , action: 5
# joint Message: [(2, 17), (5, 5), (5, 15)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : | : :_:D| : | : | : |
# | : : : :_: : : :D: : : |
# | : :D: : : | : : : : :D|
# | : : : : : | : :P: : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,4), Collided: False
# Taxi1-RED: Fuel: inf, Location: (4,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,4), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: (4, 8), Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: (0, 10), Destination: (1, 5)
# Passenger5: Location: Taxi2, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 1, 2, 4]
# ---------------------------ROUND 10---------------------------------
# changing plan acording to message
# White Taxi_2 (re)planning results:
#   # taking Red passenger, len. of plan: 18 -> active:['(2,)', '(0,)', '(2,)', '(2,)', '(2,)', '(0,)', '(0,)', '(4,)', '(1,)', '(3,)', '(3,)', '(1,)', '(3,)', '(3,)', '(3,)', '(3,)', '(0,)', '(6,)']
#   # all plans:[('Yellow', 25), ('Red', 18), ('Green', 19)]
# taxi_0 obs:
#  [ 2  4  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  4] , action: 2
# taxi_1 obs:
#  [ 4 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  4] , action: 5
# taxi_2 obs:
#  [ 1  4  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  4] , action: 2
# joint Message: [(2, 16), (5, 4), (2, 17)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : | : : :D| : | : | : |
# | : : : : :_: : :D: : : |
# | : :D: : : | : : : : :D|
# | : : : : : | : :P: : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (3,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: (4, 8), Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: (0, 10), Destination: (1, 5)
# Passenger5: Location: Taxi2, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 1, 2, 4]
# ---------------------------ROUND 11---------------------------------
# changing plan acording to message
# agent_2: no available plan found for passenger 4
# White Taxi_2 (re)planning results:
#   # taking Green passenger, len. of plan: 18 -> active:['(0,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(1,)', '(1,)', '(4,)', '(0,)', '(0,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(1,)', '(8,)']
#   # all plans:[('Yellow', 26), ('Green', 18)]
# taxi_0 obs:
#  [ 2  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  4] , action: 2
# taxi_1 obs:
#  [ 3 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  4] , action: 5
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  4] , action: 4
# joint Message: [(2, 15), (5, 3), (4, 17)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : | : : :D| : | : | : |
# | : : : : :_:_: :D: : : |
# | : :D: : : | : : : : :D|
# | : : : : : | : :P: : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,6), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,5), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: (4, 8), Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: (0, 10), Destination: (1, 5)
# Passenger5: Location: Taxi2, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 1, 2, 4]
# ---------------------------ROUND 12---------------------------------
# taxi_0 obs:
#  [ 2  6  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  4] , action: 2
# taxi_1 obs:
#  [ 2 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  4] , action: 5
# taxi_2 obs:
#  [ 2  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  4] , action: 4
# joint Message: [(2, 14), (5, 2), (4, 16)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : | : : :D| : | : | : |
# | : : : : : :_:_:D: : : |
# | : :D: : : | : : : : :D|
# | : : : : : | : :P: : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,7), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,6), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: (4, 8), Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: (0, 10), Destination: (1, 5)
# Passenger5: Location: Taxi2, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 1, 2, 4]
# ---------------------------ROUND 13---------------------------------
# taxi_0 obs:
#  [ 2  7  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  4] , action: 2
# taxi_1 obs:
#  [ 2  9  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  4] , action: 5
# taxi_2 obs:
#  [ 2  6  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  4] , action: 4
# joint Message: [(2, 13), (5, 1), (4, 15)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : | : : :D| : | : | : |
# | : : : : : : :_:D: : : |
# | : :D: : : | : : : : :D|
# | : : : : : | : :P: : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,8), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,8), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,7), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: (4, 8), Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: (0, 10), Destination: (1, 5)
# Passenger5: Location: Taxi2, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 1, 2, 4]
# ---------------------------ROUND 14---------------------------------
# taxi_0 obs:
#  [ 2  8  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  4] , action: 2
# taxi_1 obs:
#  [ 2  8  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  4] , action: 5
# taxi_2 obs:
#  [ 2  7  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  4] , action: 4
# joint Message: [(2, 12), (5, 0), (4, 14)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : | : : :D| : | : | : |
# | : : : : : : : :_: : : |
# | : :D: : : | : :_: : :D|
# | : : : : : | : :P: : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,8), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,8), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,8), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: (4, 8), Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: (0, 10), Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 1, 2, 1]
# ---------------------------ROUND 15---------------------------------
# Red Taxi_1 (re)planning results:
#   # taking Red passenger, len. of plan: 13 -> active:['(0,)', '(0,)', '(4,)', '(1,)', '(3,)', '(3,)', '(1,)', '(3,)', '(3,)', '(3,)', '(3,)', '(0,)', '(6,)']
#   # all plans:[('Yellow', 28), ('Red', 13), ('Green', 14)]
# changing plan acording to message
# Red Taxi_1 (re)planning results:
#   # taking Green passenger, len. of plan: 14 -> active:['(2,)', '(2,)', '(1,)', '(1,)', '(4,)', '(0,)', '(0,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(1,)', '(8,)']
#   # all plans:[('Yellow', 28), ('Green', 14)]
# taxi_0 obs:
#  [ 3  8  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  1] , action: 2
# taxi_1 obs:
#  [ 2  8  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  1] , action: 4
# taxi_2 obs:
#  [ 2  8  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  1] , action: 4
# joint Message: [(2, 11), (4, 13), (4, 13)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : | : : :D| : | : | : |
# | : : : : : : : : :_: : |
# | : :D: : : | : : : : :D|
# | : : : : : | : :P: : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,8), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,9), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: (4, 8), Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: (0, 10), Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 1, 2, 1]
# ---------------------------ROUND 16---------------------------------
# taxi_0 obs:
#  [ 4  8  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  1] , action: 2
# taxi_1 obs:
#  [ 2  9  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  1] , action: 4
# taxi_2 obs:
#  [ 2  9  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  2
#   1  2  1] , action: 4
# joint Message: [(2, 10), (4, 12), (4, 12)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : | : : :D| : | : | : |
# | : : : : : : : : : :_: |
# | : :D: : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,8), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,10), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: Taxi1, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: (0, 10), Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 3, 1, 2, 1]
# ---------------------------ROUND 17---------------------------------
# taxi_0 obs:
#  [ 4  8  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  2  1] , action: 2
# taxi_1 obs:
#  [ 2 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  2  1] , action: 4
# taxi_2 obs:
#  [ 2 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  2  1] , action: 4
# joint Message: [(2, 9), (4, 11), (4, 11)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : | : : :D| : | : |_: |
# | : : : : : : : : : : : |
# | : :D: : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,8), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,10), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: Taxi1, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: (0, 10), Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 3, 1, 2, 1]
# ---------------------------ROUND 18---------------------------------
# taxi_0 obs:
#  [ 3  8  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  2  1] , action: 2
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  2  1] , action: 4
# taxi_2 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  2  1] , action: 4
# joint Message: [(2, 8), (4, 10), (4, 10)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : | : : :D| : | : | : |
# | : : : : : : : : : : : |
# | : :D: : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,7), Collided: False
# Taxi1-RED: Fuel: inf, Location: (0,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (0,10), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: Taxi1, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: (0, 10), Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 3, 1, 2, 1]
# ---------------------------ROUND 19---------------------------------
# taxi_0 obs:
#  [ 3  7  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  2  1] , action: 2
# taxi_1 obs:
#  [ 0 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  2  1] , action: 4
# taxi_2 obs:
#  [ 0 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  2  1] , action: 4
# joint Message: [(2, 7), (4, 9), (4, 9)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :D| : | : | : |
# | : : : : : : : : : : : |
# | : :D: : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,6), Collided: False
# Taxi1-RED: Fuel: inf, Location: (0,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (0,10), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: Taxi1, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Taxi3, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 3, 1, 5, 1]
# ---------------------------ROUND 20---------------------------------
# taxi_0 obs:
#  [ 3  6  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 2
# taxi_1 obs:
#  [ 0 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 4
# taxi_2 obs:
#  [ 0 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 4
# joint Message: [(2, 6), (4, 8), (4, 8)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :D| : | : | : |
# | : : : : : : : : : : : |
# | : :D: : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,6), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,10), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: Taxi1, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Taxi3, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 3, 1, 5, 1]
# ---------------------------ROUND 21---------------------------------
# taxi_0 obs:
#  [ 2  6  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 2
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 4
# taxi_2 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 4
# joint Message: [(2, 5), (4, 7), (4, 7)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :D| : | : |_: |
# | : : : : : : : : : : : |
# | : :D: : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,10), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: Taxi1, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Taxi3, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 3, 1, 5, 1]
# ---------------------------ROUND 22---------------------------------
# taxi_0 obs:
#  [ 2  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 2
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 4
# taxi_2 obs:
#  [ 2 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 4
# joint Message: [(2, 4), (4, 6), (4, 6)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :D| : | : |_: |
# | : : : : : : : : : : : |
# | : :D: : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,4), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,9), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: Taxi1, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Taxi3, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 3, 1, 5, 1]
# ---------------------------ROUND 23---------------------------------
# taxi_0 obs:
#  [ 2  4  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 2
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 4
# taxi_2 obs:
#  [ 2  9  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 4
# joint Message: [(2, 3), (4, 5), (4, 5)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :D| : | : |_: |
# | : : : : : : : : : : : |
# | : :D: : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,3), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,8), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: Taxi1, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Taxi3, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 3, 1, 5, 1]
# ---------------------------ROUND 24---------------------------------
# taxi_0 obs:
#  [ 2  3  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 2
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 4
# taxi_2 obs:
#  [ 2  8  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 4
# joint Message: [(2, 2), (4, 4), (4, 4)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :D| : | : |_: |
# | : : : : : : : : : : : |
# | : :D: : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,2), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,7), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: Taxi1, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Taxi3, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 3, 1, 5, 1]
# ---------------------------ROUND 25---------------------------------
# taxi_0 obs:
#  [ 2  2  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 2
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 4
# taxi_2 obs:
#  [ 2  7  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 4
# joint Message: [(2, 1), (4, 3), (4, 3)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :D| : | : |_: |
# | : : : : : : : : : : : |
# | : :D: : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,2), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,6), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: Taxi1, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Taxi3, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 3, 1, 5, 1]
# ---------------------------ROUND 26---------------------------------
# taxi_0 obs:
#  [ 3  2  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 2
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 4
# taxi_2 obs:
#  [ 2  6  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  3
#   1  5  1] , action: 4
# joint Message: [(2, 0), (4, 2), (4, 2)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :D| : | : |_: |
# | : : : : : : : : : : : |
# | : :_: : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,2), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,5), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Taxi3, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 5, 1]
# ---------------------------ROUND 27---------------------------------
# agent_0: no available plan found for passenger 3
# Yellow Taxi_0 (re)planning results:
#   # taking Yellow passenger, len. of plan: 21 -> active:['(3,)', '(3,)', '(0,)', '(0,)', '(0,)', '(4,)', '(1,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(1,)', '(1,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(5,)']
#   # all plans:[('Yellow', 21)]
# taxi_0 obs:
#  [ 3  2  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  1
#   1  5  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  1
#   1  5  1] , action: 4
# taxi_2 obs:
#  [ 2  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  1
#   1  5  1] , action: 4
# joint Message: [(1, 20), (4, 1), (4, 1)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :D| : | : |_: |
# | : : : : : : : : : : : |
# | :_: : : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,1), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Taxi3, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 5, 1]
# ---------------------------ROUND 28---------------------------------
# taxi_0 obs:
#  [ 3  1  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  1
#   1  5  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  1
#   1  5  1] , action: 4
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  1
#   1  5  1] , action: 4
# joint Message: [(1, 19), (4, 0), (4, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# |_: : : : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 1, 1]
# ---------------------------ROUND 29---------------------------------
# Red Taxi_1 (re)planning results:
#   # taking Yellow passenger, len. of plan: 31 -> active:['(0,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(0,)', '(0,)', '(0,)', '(0,)', '(4,)', '(1,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(1,)', '(1,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(5,)']
#   # all plans:[('Yellow', 31)]
# changing plan acording to message
# agent_1: no available plan was found (for all)
# agent_1: no action available - using defualt
# White Taxi_2 (re)planning results:
#   # taking Yellow passenger, len. of plan: 26 -> active:['(3,)', '(3,)', '(3,)', '(0,)', '(3,)', '(3,)', '(0,)', '(0,)', '(0,)', '(0,)', '(4,)', '(1,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(1,)', '(1,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(5,)']
#   # all plans:[('Yellow', 26)]
# changing plan acording to message
# agent_2: no available plan was found (for all)
# agent_2: no action available - using defualt
# taxi_0 obs:
#  [ 3  0  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  1
#   1  1  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  1
#   1  1  1] , action: 0
# joint Message: [(1, 18), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :D|
# |_: : : : : | : : : : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 1, 1]
# ---------------------------ROUND 30---------------------------------
# taxi_0 obs:
#  [ 4  0  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  1
#   1  1  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  1
#   1  1  1] , action: 0
# joint Message: [(1, 17), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :D|
# | : : : : : | : : : : : |
# |_: : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 1, 1]
# ---------------------------ROUND 31---------------------------------
# taxi_0 obs:
#  [ 5  0  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  1
#   1  1  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  1
#   1  1  1] , action: 0
# joint Message: [(1, 16), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# |P| :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (6,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: (6, 0), Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 1, 1]
# ---------------------------ROUND 32---------------------------------
# taxi_0 obs:
#  [ 6  0  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  1
#   1  1  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  2  1
#   1  1  1] , action: 0
# joint Message: [(1, 15), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (6,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 33---------------------------------
# taxi_0 obs:
#  [ 6  0  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# joint Message: [(1, 14), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 34---------------------------------
# taxi_0 obs:
#  [ 5  0  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# joint Message: [(1, 13), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,1), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 35---------------------------------
# taxi_0 obs:
#  [ 5  1  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# joint Message: [(1, 12), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,2), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 36---------------------------------
# taxi_0 obs:
#  [ 5  2  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# joint Message: [(1, 11), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,3), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 37---------------------------------
# taxi_0 obs:
#  [ 5  3  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# joint Message: [(1, 10), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,4), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 38---------------------------------
# taxi_0 obs:
#  [ 5  4  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# joint Message: [(1, 9), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 39---------------------------------
# taxi_0 obs:
#  [ 5  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# joint Message: [(1, 8), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,6), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 40---------------------------------
# taxi_0 obs:
#  [ 5  6  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# joint Message: [(1, 7), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,6), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 41---------------------------------
# taxi_0 obs:
#  [ 4  6  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# joint Message: [(1, 6), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,6), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 42---------------------------------
# taxi_0 obs:
#  [ 3  6  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# joint Message: [(1, 5), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,7), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 43---------------------------------
# taxi_0 obs:
#  [ 3  7  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# joint Message: [(1, 4), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,8), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 44---------------------------------
# taxi_0 obs:
#  [ 3  8  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# joint Message: [(1, 3), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,9), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 45---------------------------------
# taxi_0 obs:
#  [ 3  9  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# joint Message: [(1, 2), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,10), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 46---------------------------------
# taxi_0 obs:
#  [ 3 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# joint Message: [(1, 1), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :D|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,11), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 47---------------------------------
# taxi_0 obs:
#  [ 3 11  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 1
# taxi_1 obs:
#  [ 1 10  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  5  6  0  4  8  2  2  0 10  4 10  3 11  3  2  1  2  1  5  2  8  3  1
#   1  1  1] , action: 0
# joint Message: [(1, 0), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : :_| : | : |_: |
# | : : : : : : : : : : : |
# | : : : : : | : : : : :_|
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,11), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,10), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: Arrived!, Destination: (3, 11)
# Passenger2: Location: Arrived!, Destination: (3, 2)
# Passenger3: Location: Arrived!, Destination: (1, 2)
# Passenger4: Location: Arrived!, Destination: (1, 5)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: True, {'taxi_0': True, 'taxi_1': True, 'taxi_2': True, '__all__': True}
# Passengers Status's: [1, 1, 1, 1, 1]
# ----------------------------------
#  total reward of all agents: 657, {'taxi_0': 257, 'taxi_1': 124, 'taxi_2': 276}
# ----------------------------------
# Thats all - part 2.2

# %% [markdown]
# We can see a major performence improvement - this method can easily solve a wide, Multi-Agent domain, using low-bandwidth com.
#
# After we thought about the solution of the 5th and final step ('Interpretation') by ourself, We can design a RL Agent that can learn how to interpret and act by it own.
# #### PPO RL agent learn how to act in the high-level action space (X - handling passenger x, 0 - stby)
#
# we show how high-level single agent can learn how to act.
# further research - learning what to communicate (cooperative/adverserial), and learning how to interpret-act acorrding to other agents 'signals'

# %%
"""
part 3 - 
agents learn now - high level PPO, low-level a-star
"""

from src.decision_makers.High_level_learner import LearningHighLevelDecisionMaker

env = MultiTaxiEnv(num_taxis=1, num_passengers=2, domain_map=MAP2, observation_type='symbolic', option_to_stand_by=True)
env.agents = env.taxis_names
env = EnvWrappper(env, env.agents)
env = Multi_Taxi_Task_Wrapper(env)
obs = env.reset()

D_M = LearningHighLevelDecisionMaker(env.action_space)
obs = env.reset()
env.env.env.render()
for i in range(50):
    print(f"obs:{type(obs)}")
    a = D_M.get_action(obs)
    print(f"next action: {env.index_action_dictionary[a]}")
    obs, r, done, info = env.step(a)
    env.env.env.render()
    if done: break
print("that all - part 3")
# Out:
# +-------+
# | :P|D: |
# | :D| : |
# | : : : |
# | |P:G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,1), Collided: False
# Passenger1: Location: (0, 1), Destination: (1, 1)
# Passenger2: Location: (3, 1), Destination: (0, 2)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [2, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 1
# +-------+
# | : |D: |
# | :D| : |
# | : : : |
# | |P:G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,1), Collided: False
# Passenger1: Location: Taxi1, Destination: (1, 1)
# Passenger2: Location: (3, 1), Destination: (0, 2)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [3, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 1
# +-------+
# | : |D: |
# | :D| : |
# | : : : |
# | |P:G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (1,1), Collided: False
# Passenger1: Location: Taxi1, Destination: (1, 1)
# Passenger2: Location: (3, 1), Destination: (0, 2)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [3, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 1
# +-------+
# | : |D: |
# | :_| : |
# | : : : |
# | |P:G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (1,1), Collided: False
# Passenger1: Location: Arrived!, Destination: (1, 1)
# Passenger2: Location: (3, 1), Destination: (0, 2)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [1, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 2
# +-------+
# | : |D: |
# | : | : |
# | :_: : |
# | |P:G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,1), Collided: False
# Passenger1: Location: Arrived!, Destination: (1, 1)
# Passenger2: Location: (3, 1), Destination: (0, 2)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [1, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 2
# +-------+
# | : |D: |
# | : | : |
# | : : : |
# | |P:G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,1), Collided: False
# Passenger1: Location: Arrived!, Destination: (1, 1)
# Passenger2: Location: (3, 1), Destination: (0, 2)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [1, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 2
# +-------+
# | : |D: |
# | : | : |
# | : : : |
# | | :G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,1), Collided: False
# Passenger1: Location: Arrived!, Destination: (1, 1)
# Passenger2: Location: Taxi1, Destination: (0, 2)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [1, 3]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 2
# +-------+
# | : |D: |
# | : | : |
# | : : : |
# | | :G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,1), Collided: False
# Passenger1: Location: Arrived!, Destination: (1, 1)
# Passenger2: Location: Taxi1, Destination: (0, 2)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [1, 3]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 2
# +-------+
# | : |D: |
# | : | : |
# | : : : |
# | | :G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,2), Collided: False
# Passenger1: Location: Arrived!, Destination: (1, 1)
# Passenger2: Location: Taxi1, Destination: (0, 2)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [1, 3]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 2
# +-------+
# | : |D: |
# | : | : |
# | : : : |
# | | :G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (1,2), Collided: False
# Passenger1: Location: Arrived!, Destination: (1, 1)
# Passenger2: Location: Taxi1, Destination: (0, 2)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [1, 3]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 2
# +-------+
# | : |D: |
# | : | : |
# | : : : |
# | | :G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,2), Collided: False
# Passenger1: Location: Arrived!, Destination: (1, 1)
# Passenger2: Location: Taxi1, Destination: (0, 2)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [1, 3]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 2
# +-------+
# | : |F: |
# | : | : |
# | : : : |
# | | :G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,2), Collided: False
# Passenger1: Location: Arrived!, Destination: (1, 1)
# Passenger2: Location: Arrived!, Destination: (0, 2)
# Done: True, {'taxi_0': True, '__all__': True}
# Passengers Status's: [1, 1]
# that all - part 3

# %% [markdown]
# ## Compilling Communication for RL as an Action + Com-Reward
#
# To explain implicit communication we will look at the Speaker Lister environment. In this environment there are 2 agents in which one agent (speaker) has information about the goal and has a limmited mode of communication with the second agent (listener) must use the speaker's communications and its limitted observations to navigate a 2D space toward the goal. The speaker agent cannot navigate, and the listener object cannot communicate.
#
# We used this setting to implement our emergent communication in the form of deciding when to 'communicate' - SPEAKER will allways 'point' on the right target, Listener should learn when to use the action to observe the Speaker's pointer (or in other wards, Listener learns when to ask for help).

# %% [markdown]
# #### speaker-listener com as action - env-wrapper
# #### speaker - 'point-to-target' if asked, listener can ask for 'help' from speaker (action 0 - no move)
# <img src='images/seaker-point.jpg' width="500" height="500">
#
# ##### Listener new-wrapper :
# The speaker observation is of type `Box(-inf, inf, (9,), float32)`
# 1. listener agent velocity X
# 2. listener agent velocity Y
# 3. red landmark X pos - listener agent X pos
# 4. red landmark Y pos - listener agent Y pos
# 5. blue landmark X pos - listener agent X pos
# 6. blue landmark Y pos - listener agent Y pos
# 7. green landmark X pos - listener agent X pos
# 8. green landmark Y pos - listener agent Y pos
# 9. communication channel -
#     if com action was choosen last - speaker 'points' at destination (1-8 - directions shown above). else (no com from SPEAKER) - 0
# ##### Discrete ACTIONS:
# * 0 - do nothing and ask for communicate (com penalty)
# * 1 - push left (add velocity in negative x-axis direction)
# * 2 - push right (add velocity in positive x-axis direction)
# * 3 - push down (add velocity in negative y-axis direction)
# * 4 - push up (add velocity in positive t-axis direction)

# %%
import numpy as np
from gym import Wrapper
from copy import deepcopy
from pettingzoo.mpe import simple_speaker_listener_v3
from stable_baselines3 import PPO

# speaker action-to-index dict
SPEAKER_DISCRETE_ACTIONS = {

    'A': 0,
    'B': 1,
    'C': 2,
    'nothing' : 3,

}

# listener action-to-index dict
LISTENER_DISCRETE_ACTIONS = {
    'nothing': 0,
    'left':    1,
    'right':   2,
    'down':    3,
    'up':      4
}

from gym.spaces import Discrete, Box

"""#### Custom gym Wrapper
"""
class ListenerOnlyCOMWrapper(Wrapper):

    def __init__(self, env, com_allways_on = False, com_reward = -0.1):
        super().__init__(env)
        self.com_allways_on = com_allways_on
        self.com_reward = com_reward

        # reset to skip speaker before new game
        self.obs = self.reset()

        # set single agent list
        self.agents = self.agents[1:]

        self.observation_space = self.get_observation_space()

        #set action space (listener)
        self.action_space = env.action_spaces[self.agents[0]]

    def get_observation_space(self):
        return Box(low=-np.inf,high=np.inf , shape= (len(self.obs),), dtype=np.float32)

    def reset(self):
        super().reset()


        # skip speaker action
        self.__step_speaker()
        self.obs,_,_,_ = self.env.last()
        self.obs = self.fix_obs(self.obs, self.com_allways_on)
        return self.obs

    def step(self, action):
        # CHANGE ACTION AS NEEDED
        com = action == 0
        super().step(action)
        ob, _, done, _ = self.env.last()  # do listener action

        # skip speaker action - if com==True, speaker 'speaks' else - 0 speak will be performed
        self.__step_speaker()

        step_rets = self.env.last()

        if self.com_allways_on:  com = True

        self.obs = self.fix_obs(step_rets[0], com)

        reward_com = 0
        if com:
            # get - minus-reward for com use - adjust reward by initializing
            if not self.com_allways_on: reward_com = self.com_reward

        return (self.obs,step_rets[1] + reward_com, step_rets[2], step_rets[3])

    def fix_obs(self, obs, com):
        if len(obs)<5: return obs
        obs = np.array(obs[:-2])
        point = int(obs[-1])
        if not com or point==3:
            obs[-1] = 0
            return obs
        try:
            x = obs[2+point*2]
            y = obs[3+point*2]
        except:
            print('out of bounds')
        myradians = math.atan2(y, x)
        deg = int(math.degrees(myradians))
        if deg<0:
            deg+=360
        output = deg // 45
        obs[-1] = (output+1)
        return obs

    def __step_speaker(self):
        goal_color, _, done, _ = self.env.last()

        # speaker is done before the listener.
        if done:
            return

        # step with the correct action type
        if self.env.unwrapped.continuous_actions:
            super().step(goal_color)
        else:
            super().step(np.argmax(goal_color))

env = simple_speaker_listener_v3.env(max_cycles=200, continuous_actions=False)
env = ListenerOnlyCOMWrapper(env, com_allways_on=False)
print(f'custom wrapped environment: {env}')

#train PPO agent method
def train_model(env):
    env_copy = deepcopy(env)
    env_copy.reset()
    model = PPO("MlpPolicy", env_copy, verbose=1)
    for batch in range(200):
        print(f"batch: {batch}")
        model.learn(total_timesteps=8000, n_eval_episodes=40)
        env_copy.reset()
    return model

def get_ppo_agent(is_com_active):
    if is_com_active:
        model_file_name = 'S-L_PPO_base'
    else:
        model_file_name = 'S-L_PPO_com10'
    try:
        model = PPO.load(model_file_name)
    except:
        model = train_model(env)
        model.save(model_file_name)
    return model

# run (n_iter) episodes after training and render
def run(env,model,n_iter):
    for m in range(n_iter):
        observation = env.reset()
        env.render()
        for i in range(env.unwrapped.max_cycles):
            # choose an action and execute
            action = model.predict(observation)
            action = action[0]
            print(f'step {i}')
            print(f'observation: {observation}')
            observation, reward, done, info = env.step(action)

            # log everything
            c = "no_com"
            if action == 0 or env.com_allways_on: c = "com active"
            print(f'action:      {action}  com:{c}')
            print(f'reward:      {reward}')
            print()

            # if done, the episode is complete. no more actions can be taken
            if done:
                break

            env.render()
        env.close()

model = get_ppo_agent(env.com_allways_on)

run(env,model,5)

print("that all - part 4")
# Out:
# custom wrapped environment: <ListenerOnlyCOMWrappersimple_speaker_listener_v3>
# step 0
# observation: [ 0.          0.          1.0223006  -0.9109972  -0.5290924  -0.26840162
#  -0.69068325  0.3932359   0.        ]
# action:      1  com:no_com
# reward:      -0.3015689154408136
#
# step 1
# observation: [-0.5         0.          1.0723007  -0.9109972  -0.47909236 -0.26840162
#  -0.64068323  0.3932359   0.        ]
# action:      0  com:com active
# reward:      -0.36704323920623083
#
# step 2
# observation: [-0.375       0.          1.1098007  -0.9109972  -0.44159234 -0.26840162
#  -0.6031832   0.3932359   8.        ]
# action:      0  com:com active
# reward:      -0.34299468515529385
#
# step 3
# observation: [-0.28125     0.          1.1379256  -0.9109972  -0.41346735 -0.26840162
#  -0.5750582   0.3932359   8.        ]
# action:      2  com:no_com
# reward:      -0.26773383760434716
#
# step 4
# observation: [ 0.2890625   0.          1.1090194  -0.9109972  -0.4423736  -0.26840162
#  -0.60396445  0.3932359   0.        ]
# action:      1  com:no_com
# reward:      -0.24347956052858805
#
# step 5
# observation: [-0.28320312  0.          1.1373397  -0.9109972  -0.4140533  -0.26840162
#  -0.57564414  0.3932359   0.        ]
# action:      3  com:no_com
# reward:      -0.20200136719990605
#
# step 6
# observation: [-0.21240234 -0.5         1.15858    -0.8609972  -0.39281306 -0.21840163
#  -0.5544039   0.44323587  0.        ]
# action:      4  com:no_com
# reward:      -0.19535626652428562
#
# step 7
# observation: [-0.15930176  0.125       1.1745101  -0.8734972  -0.37688288 -0.23090163
#  -0.5384737   0.4307359   0.        ]
# action:      3  com:no_com
# reward:      -0.16938292977113267
#
# step 8
# observation: [-0.11947632 -0.40625     1.1864578  -0.8328722  -0.36493525 -0.19027664
#  -0.5265261   0.4713609   0.        ]
# action:      4  com:no_com
# reward:      -0.17073720705708567
#
# step 9
# observation: [-0.08960724  0.1953125   1.1954185  -0.85240346 -0.35597453 -0.20980789
#  -0.51756537  0.45182964  0.        ]
# action:      3  com:no_com
# reward:      -0.15241334876069654
#
# step 10
# observation: [-0.06720543 -0.35351562  1.202139   -0.8170519  -0.34925398 -0.17445631
#  -0.5108448   0.4871812   0.        ]
# action:      3  com:no_com
# reward:      -0.1280757448246315
#
# step 11
# observation: [-0.05040407 -0.7651367   1.2071794  -0.74053824 -0.34421358 -0.09794265
#  -0.5058044   0.5636949   0.        ]
# action:      2  com:no_com
# reward:      -0.15408303730865383
#
# step 12
# observation: [ 0.46219695 -0.57385254  1.1609597  -0.683153   -0.39043325 -0.04055739
#  -0.5520241   0.6210801   0.        ]
# action:      2  com:no_com
# reward:      -0.22572430275404795
#
# step 13
# observation: [ 0.84664774 -0.4303894   1.076295   -0.640114   -0.47509804  0.00248155
#  -0.6366889   0.66411906  0.        ]
# action:      1  com:no_com
# reward:      -0.2399349622334742
#
# step 14
# observation: [ 0.13498577 -0.32279205  1.0627964  -0.6078348  -0.48859662  0.03476075
#  -0.6501875   0.69639826  0.        ]
# action:      4  com:no_com
# reward:      -0.24880264950095143
#
# step 15
# observation: [ 0.10123934  0.25790596  1.0526725  -0.6336254  -0.49872056  0.00897016
#  -0.6603114   0.6706077   0.        ]
# action:      1  com:no_com
# reward:      -0.20832960419570815
#
# step 16
# observation: [-0.4240705   0.19342947  1.0950795  -0.65296835 -0.4563135  -0.01037279
#  -0.61790437  0.6512647   0.        ]
# action:      3  com:no_com
# reward:      -0.18083823619097913
#
# step 17
# observation: [-0.3180529  -0.3549279   1.1268848  -0.61747557 -0.4245082   0.02512
#  -0.5860991   0.6867575   0.        ]
# action:      3  com:no_com
# reward:      -0.1708747695242788
#
# step 18
# observation: [-0.23853965 -0.7661959   1.1507387  -0.540856   -0.40065426  0.10173959
#  -0.56224513  0.76337713  0.        ]
# action:      0  com:com active
# reward:      -0.271854109867627
#
# step 19
# observation: [-0.17890474 -0.57464695  1.1686292  -0.48339128 -0.38276377  0.15920429
#  -0.5443546   0.8208418   8.        ]
# action:      0  com:com active
# reward:      -0.27734283156828576
#
# step 20
# observation: [-0.13417855 -0.4309852   1.1820471  -0.44029278 -0.3693459   0.20230281
#  -0.5309368   0.8639403   8.        ]
# action:      0  com:com active
# reward:      -0.2841336195930504
#
# step 21
# observation: [-0.10063392 -0.3232389   1.1921104  -0.40796888 -0.35928252  0.2346267
#  -0.52087337  0.8962642   8.        ]
# action:      2  com:no_com
# reward:      -0.22840447251754284
#
# step 22
# observation: [ 0.42452458 -0.24242918  1.149658   -0.38372597 -0.40173498  0.25886962
#  -0.5633258   0.92050713  0.        ]
# action:      4  com:no_com
# reward:      -0.23953921515306395
#
# step 23
# observation: [ 0.3183934   0.31817812  1.1178187  -0.41554376 -0.43357432  0.22705181
#  -0.5951652   0.88868934  0.        ]
# action:      4  com:no_com
# reward:      -0.23273070603351326
#
# step 24
# observation: [ 0.23879507  0.7386336   1.0939392  -0.48940712 -0.45745382  0.15318844
#  -0.6190447   0.81482595  0.        ]
# action:      4  com:no_com
# reward:      -0.22825439154626426
#
# step 25
# observation: [ 0.1790963   1.0539752   1.0760295  -0.59480464 -0.47536346  0.04779093
#  -0.6369543   0.7094284   0.        ]
# action:      3  com:no_com
# reward:      -0.23927251112501075
#
# step 26
# observation: [ 0.13432223  0.2904814   1.0625973  -0.6238528  -0.48879567  0.01874279
#  -0.6503866   0.6803803   0.        ]
# action:      1  com:no_com
# reward:      -0.20149340331924048
#
# step 27
# observation: [-0.39925835  0.21786104  1.1025231  -0.6456389  -0.44886985 -0.00304332
#  -0.6104607   0.6585942   0.        ]
# action:      2  com:no_com
# reward:      -0.22026679718073774
#
# step 28
# observation: [ 0.20055625  0.16339578  1.0824676  -0.6619785  -0.46892548 -0.0193829
#  -0.63051635  0.6422546   0.        ]
# action:      4  com:no_com
# reward:      -0.24088893862462088
#
# step 29
# observation: [ 0.1504172   0.62254685  1.0674258  -0.72423315 -0.48396719 -0.08163758
#  -0.64555806  0.5799999   0.        ]
# action:      1  com:no_com
# reward:      -0.2147144388501882
#
# step 30
# observation: [-0.38718712  0.46691012  1.1061445  -0.77092415 -0.44524848 -0.12832859
#  -0.60683936  0.5333089   0.        ]
# action:      4  com:no_com
# reward:      -0.21874718517735012
#
# step 31
# observation: [-0.29039034  0.8501826   1.1351836  -0.8559424  -0.41620946 -0.21334685
#  -0.57780033  0.44829065  0.        ]
# action:      0  com:com active
# reward:      -0.33236541793360075
#
# step 32
# observation: [-0.21779275  0.63763696  1.1569629  -0.9197061  -0.39443016 -0.27711055
#  -0.55602103  0.38452697  8.        ]
# action:      4  com:no_com
# reward:      -0.28353136541334356
#
# step 33
# observation: [-0.16334456  0.97822773  1.1732973  -1.0175289  -0.37809572 -0.37493333
#  -0.53968656  0.28670418  0.        ]
# action:      2  com:no_com
# reward:      -0.3739002066835405
#
# step 34
# observation: [ 0.3774916   0.7336708   1.1355481  -1.090896   -0.4158449  -0.4483004
#  -0.57743573  0.21333712  0.        ]
# action:      3  com:no_com
# reward:      -0.4027794089079376
#
# step 35
# observation: [ 0.2831187   0.05025309  1.1072363  -1.0959213  -0.44415674 -0.45332572
#  -0.60574764  0.20831181  0.        ]
# action:      3  com:no_com
# reward:      -0.3823145373841803
#
# step 36
# observation: [ 0.21233901 -0.4623102   1.0860023  -1.0496902  -0.46539065 -0.4070947
#  -0.6269815   0.25454283  0.        ]
# action:      3  com:no_com
# reward:      -0.33562073507663526
#
# step 37
# observation: [ 0.15925425 -0.8467326   1.070077   -0.965017   -0.48131606 -0.32242143
#  -0.64290696  0.33921608  0.        ]
# action:      1  com:no_com
# reward:      -0.26351729401925966
#
# step 38
# observation: [-0.3805593  -0.63504946  1.1081328  -0.901512   -0.44326013 -0.25891647
#  -0.604851    0.40272105  0.        ]
# action:      1  com:no_com
# reward:      -0.17766187996471874
#
# step 39
# observation: [-0.78541946 -0.4762871   1.1866748  -0.8538833  -0.3647182  -0.21128777
#  -0.5263091   0.45034975  0.        ]
# action:      1  com:no_com
# reward:      -0.09626314400191413
#
# step 40
# observation: [-1.0890646  -0.35721534  1.2955812  -0.8181618  -0.25581172 -0.17556623
#  -0.4174026   0.4860713   0.        ]
# action:      0  com:com active
# reward:      -0.15245593880454955
#
# step 41
# observation: [-0.81679845 -0.2679115   1.3772612  -0.79137063 -0.17413189 -0.14877509
#  -0.33572274  0.51286244  8.        ]
# action:      4  com:no_com
# reward:      -0.04466724559606315
#
# step 42
# observation: [-0.61259884  0.29906636  1.438521   -0.82127726 -0.112872   -0.17868172
#  -0.27446288  0.48295578  0.        ]
# action:      2  com:no_com
# reward:      -0.054117858891986434
#
# step 43
# observation: [ 0.04055087  0.22429979  1.4344659  -0.84370726 -0.11692709 -0.2011117
#  -0.27851796  0.4605258   0.        ]
# action:      2  com:no_com
# reward:      -0.0763845656039267
#
# step 44
# observation: [ 0.53041315  0.16822484  1.3814245  -0.8605298  -0.16996841 -0.21793418
#  -0.33155927  0.44370332  0.        ]
# action:      3  com:no_com
# reward:      -0.07659348619949254
#
# step 45
# observation: [ 0.39780986 -0.37383136  1.3416436  -0.82314664 -0.20974939 -0.18055104
#  -0.37134025  0.48108646  0.        ]
# action:      4  com:no_com
# reward:      -0.09841282958088889
#
# step 46
# observation: [ 0.2983574   0.21962647  1.3118079  -0.8451093  -0.23958513 -0.2025137
#  -0.401176    0.45912382  0.        ]
# action:      0  com:com active
# reward:      -0.2165787817332148
#
# step 47
# observation: [ 0.22376806  0.16471985  1.2894311  -0.86158127 -0.26196194 -0.21898568
#  -0.4235528   0.44265184  8.        ]
# action:      4  com:no_com
# reward:      -0.1568505249081218
#
# step 48
# observation: [ 0.16782604  0.62353987  1.2726485  -0.92393523 -0.27874455 -0.28133968
#  -0.44033542  0.38029784  0.        ]
# action:      3  com:no_com
# reward:      -0.1622165160401472
#
# step 49
# observation: [ 0.12586953 -0.03234508  1.2600615  -0.9207007  -0.2913315  -0.27810517
#  -0.45292237  0.38353235  0.        ]
# action:      3  com:no_com
# reward:      -0.14139475449024214
#
# step 50
# observation: [ 0.09440214 -0.5242588   1.2506213  -0.86827487 -0.3007717  -0.22567928
#  -0.4623626   0.43595824  0.        ]
# action:      0  com:com active
# reward:      -0.22950277108317188
#
# step 51
# observation: [ 0.07080161 -0.3931941   1.2435411  -0.8289554  -0.30785188 -0.18635987
#  -0.46944273  0.47527766  8.        ]
# action:      2  com:no_com
# reward:      -0.15649492229299078
#
# step 52
# observation: [ 0.5531012  -0.2948956   1.188231   -0.7994659  -0.36316198 -0.1568703
#  -0.52475286  0.5047672   0.        ]
# action:      2  com:no_com
# reward:      -0.22486010060967027
#
# step 53
# observation: [ 0.9148259  -0.22117169  1.0967485  -0.7773487  -0.4546446  -0.13475314
#  -0.61623544  0.5268844   0.        ]
# action:      3  com:no_com
# reward:      -0.2784438897380146
#
# step 54
# observation: [ 0.68611944 -0.6658788   1.0281365  -0.71076083 -0.52325654 -0.06816526
#  -0.6848474   0.59347224  0.        ]
# action:      4  com:no_com
# reward:      -0.33495244344338737
#
# step 55
# observation: [ 5.1458955e-01  5.9092644e-04  9.7667754e-01 -7.1081990e-01
#  -5.7471550e-01 -6.8224356e-02 -7.3630637e-01  5.9341317e-01
#   0.0000000e+00]
# action:      1  com:no_com
# reward:      -0.32197842554365436
#
# step 56
# observation: [-1.14057824e-01  4.43194818e-04  9.88083303e-01 -7.10864246e-01
#  -5.63309669e-01 -6.82686716e-02 -7.24900544e-01  5.93368828e-01
#   0.00000000e+00]
# action:      3  com:no_com
# reward:      -0.3080884690013221
#
# step 57
# observation: [-0.08554336 -0.4996676   0.99663764 -0.6608975  -0.55475533 -0.01830191
#  -0.7163462   0.6433356   0.        ]
# action:      1  com:no_com
# reward:      -0.24870997401708475
#
# step 58
# observation: [-0.56415755 -0.3747507   1.0530534  -0.6234224  -0.4983396   0.01917316
#  -0.65993047  0.6808107   0.        ]
# action:      4  com:no_com
# reward:      -0.20796874914587352
#
# step 59
# observation: [-0.42311814  0.21893698  1.0953652  -0.6453161  -0.4560278  -0.00272054
#  -0.6176187   0.65891695  0.        ]
# action:      0  com:com active
# reward:      -0.28039171148466757
#
# step 60
# observation: [-0.31733862  0.16420273  1.127099   -0.66173637 -0.42429394 -0.01914081
#  -0.5858848   0.6424967   8.        ]
# action:      4  com:no_com
# reward:      -0.16703015553384684
#
# step 61
# observation: [-0.23800395  0.623152    1.1508994  -0.7240516  -0.40049353 -0.08145602
#  -0.5620844   0.5801815   0.        ]
# action:      3  com:no_com
# reward:      -0.15252990366325125
#
# step 62
# observation: [-0.17850296 -0.03263596  1.1687498  -0.720788   -0.38264325 -0.07819242
#  -0.5442341   0.5834451   0.        ]
# action:      1  com:no_com
# reward:      -0.10766134848042384
#
# step 63
# observation: [-0.6338772  -0.02447697  1.2321374  -0.7183403  -0.31925553 -0.07574473
#  -0.48084638  0.5858928   0.        ]
# action:      4  com:no_com
# reward:      -0.08918232004403329
#
# step 64
# observation: [-0.47540793  0.48164228  1.2796782  -0.7665045  -0.27171472 -0.12390895
#  -0.4333056   0.53772855  0.        ]
# action:      4  com:no_com
# reward:      -0.0998374053429412
#
# step 65
# observation: [-0.35655594  0.8612317   1.3153338  -0.8526277  -0.23605913 -0.21003212
#  -0.39765     0.45160538  0.        ]
# action:      2  com:no_com
# reward:      -0.14266414782775094
#
# step 66
# observation: [ 0.23258305  0.6459238   1.2920755  -0.91722006 -0.25931743 -0.2746245
#  -0.4209083   0.38701302  0.        ]
# action:      2  com:no_com
# reward:      -0.2111462963747115
#
# step 67
# observation: [ 0.6744373   0.48444283  1.2246318  -0.9656643  -0.32676116 -0.32306877
#  -0.48835203  0.33856872  0.        ]
# action:      3  com:no_com
# reward:      -0.23811805878946532
#
# step 68
# observation: [ 0.50582796 -0.13666788  1.174049   -0.9519976  -0.37734395 -0.309402
#  -0.5389348   0.35223553  0.        ]
# action:      1  com:no_com
# reward:      -0.2229221127727815
#
# step 69
# observation: [-0.12062903 -0.10250091  1.1861119  -0.9417475  -0.36528105 -0.2991519
#  -0.5268719   0.36248562  0.        ]
# action:      3  com:no_com
# reward:      -0.18520760330829708
#
# step 70
# observation: [-0.09047177 -0.5768757   1.1951591  -0.8840599  -0.3562339  -0.24146433
#  -0.51782477  0.42017317  0.        ]
# action:      3  com:no_com
# reward:      -0.14407709558231716
#
# step 71
# observation: [-0.06785383 -0.93265676  1.2019445  -0.79079425 -0.3494485  -0.14819866
#  -0.5110394   0.5134389   0.        ]
# action:      4  com:no_com
# reward:      -0.13503134769876574
#
# step 72
# observation: [-0.05089037 -0.19949257  1.2070335  -0.770845   -0.34435946 -0.1282494
#  -0.50595033  0.53338814  0.        ]
# action:      0  com:com active
# reward:      -0.22880336767500614
#
# step 73
# observation: [-0.03816778 -0.14961943  1.2108504  -0.75588304 -0.34054267 -0.11328746
#  -0.50213355  0.54835004  8.        ]
# action:      2  com:no_com
# reward:      -0.16071332877259947
#
# step 74
# observation: [ 0.47137415 -0.11221457  1.1637129  -0.74466157 -0.3876801  -0.102066
#  -0.549271    0.5595715   0.        ]
# action:      1  com:no_com
# reward:      -0.14792404586115204
#
# step 75
# observation: [-0.14646937 -0.08416093  1.1783599  -0.73624545 -0.37303317 -0.09364991
#  -0.53462404  0.5679876   0.        ]
# action:      2  com:no_com
# reward:      -0.17741141905909696
#
# step 76
# observation: [ 0.39014795 -0.06312069  1.139345   -0.72993344 -0.41204795 -0.08733784
#  -0.57363886  0.5742997   0.        ]
# action:      2  com:no_com
# reward:      -0.2482079751772568
#
# step 77
# observation: [ 0.792611   -0.04734052  1.060084   -0.72519934 -0.49130905 -0.08260379
#  -0.6528999   0.57903373  0.        ]
# action:      4  com:no_com
# reward:      -0.3199856790285818
#
# step 78
# observation: [ 0.5944582   0.46449462  1.0006381  -0.7716488  -0.5507549  -0.12905325
#  -0.7123458   0.53258425  0.        ]
# action:      3  com:no_com
# reward:      -0.36739983024116335
#
# step 79
# observation: [ 0.44584367 -0.15162905  0.95605373 -0.75648594 -0.59533924 -0.11389034
#  -0.7569301   0.5477472   0.        ]
# action:      1  com:no_com
# reward:      -0.34549339566824805
#
# step 80
# observation: [-0.16561724 -0.11372178  0.9726155  -0.74511373 -0.57877755 -0.10251816
#  -0.74036837  0.55911934  0.        ]
# action:      1  com:no_com
# reward:      -0.27545769427744005
#
# step 81
# observation: [-0.6242129  -0.08529133  1.0350368  -0.7365846  -0.5163562  -0.09398903
#  -0.6779471   0.5676485   0.        ]
# action:      4  com:no_com
# reward:      -0.2393996641972474
#
# step 82
# observation: [-0.4681597   0.4360315   1.0818528  -0.7801877  -0.46954027 -0.13759218
#  -0.6311311   0.52404535  0.        ]
# action:      3  com:no_com
# reward:      -0.20319870991862857
#
# step 83
# observation: [-0.3511198  -0.17297637  1.1169647  -0.7628901  -0.43442827 -0.12029454
#  -0.59601915  0.541343    0.        ]
# action:      3  com:no_com
# reward:      -0.1698266903165877
#
# step 84
# observation: [-0.26333982 -0.6297323   1.1432987  -0.6999169  -0.4080943  -0.05732132
#  -0.56968516  0.6043162   0.        ]
# action:      1  com:no_com
# reward:      -0.11457837125148555
#
# step 85
# observation: [-0.6975049  -0.47229922  1.2130492  -0.65268695 -0.3383438  -0.0100914
#  -0.49993467  0.6515461   0.        ]
# action:      2  com:no_com
# reward:      -0.11355845875754522
#
# step 86
# observation: [-0.02312865 -0.3542244   1.2153621  -0.6172645  -0.33603096  0.02533105
#  -0.4976218   0.68696856  0.        ]
# action:      4  com:no_com
# reward:      -0.1117576162447459
#
# step 87
# observation: [-0.01734649  0.2343317   1.2170967  -0.6406977  -0.3342963   0.00189788
#  -0.49588716  0.6635354   0.        ]
# action:      0  com:com active
# reward:      -0.21113164505205578
#
# step 88
# observation: [-0.01300987  0.17574877  1.2183977  -0.65827256 -0.3329953  -0.015677
#  -0.49458617  0.6459605   8.        ]
# action:      2  com:no_com
# reward:      -0.14677174531675044
#
# step 89
# observation: [ 0.4902426   0.13181157  1.1693734  -0.6714537  -0.38201958 -0.02885816
#  -0.54361045  0.63277936  0.        ]
# action:      4  com:no_com
# reward:      -0.18325869445588677
#
# step 90
# observation: [ 0.36768195  0.59885865  1.1326052  -0.7313396  -0.41878778 -0.08874403
#  -0.58037865  0.5728935   0.        ]
# action:      3  com:no_com
# reward:      -0.2062394738357664
#
# step 91
# observation: [ 0.27576146 -0.05085599  1.1050291  -0.726254   -0.44636393 -0.08365843
#  -0.6079548   0.5779791   0.        ]
# action:      0  com:com active
# reward:      -0.32450708650853893
#
# step 92
# observation: [ 0.2068211  -0.03814199  1.084347   -0.7224398  -0.46704602 -0.07984423
#  -0.6286369   0.5817933   8.        ]
# action:      1  com:no_com
# reward:      -0.19303255152807358
#
# step 93
# observation: [-0.3448842  -0.02860649  1.1188354  -0.71957916 -0.4325576  -0.07698358
#  -0.59414846  0.5846539   0.        ]
# action:      1  com:no_com
# reward:      -0.1328294162996674
#
# step 94
# observation: [-0.7586631  -0.02145487  1.1947017  -0.7174337  -0.3566913  -0.07483809
#  -0.5182822   0.58679944  0.        ]
# action:      0  com:com active
# reward:      -0.19523745943306703
#
# step 95
# observation: [-0.5689973  -0.01609115  1.2516015  -0.71582454 -0.29979154 -0.07322898
#  -0.46138242  0.5884085   8.        ]
# action:      0  com:com active
# reward:      -0.1712962137201378
#
# step 96
# observation: [-0.426748   -0.01206836  1.2942762  -0.7146177  -0.25711676 -0.07202214
#  -0.4187076   0.58961535  8.        ]
# action:      1  com:no_com
# reward:      -0.03572137026437999
#
# step 97
# observation: [-0.820061   -0.00905127  1.3762823  -0.7137126  -0.17511065 -0.07111701
#  -0.3367015   0.5905205   0.        ]
# action:      2  com:no_com
# reward:      -0.03172848391130595
#
# step 98
# observation: [-0.11504576 -0.00678845  1.3877869  -0.71303374 -0.16360608 -0.07043817
#  -0.32519695  0.59119934  0.        ]
# action:      3  com:no_com
# reward:      -0.02441523688044176
#
# step 99
# observation: [-0.08628432 -0.50509137  1.3964154  -0.6625246  -0.15497765 -0.01992903
#  -0.31656852  0.6417085   0.        ]
# action:      4  com:no_com
# reward:      -0.023081149421315686
#
# step 100
# observation: [-0.06471324  0.1211815   1.4028866  -0.67464274 -0.14850633 -0.03204718
#  -0.3100972   0.62959033  0.        ]
# action:      3  com:no_com
# reward:      -0.02071470923661379
#
# step 101
# observation: [-0.04853493 -0.40911388  1.4077401  -0.63373137 -0.14365283  0.0088642
#  -0.3052437   0.6705017   0.        ]
# action:      3  com:no_com
# reward:      -0.02762235735705485
#
# step 102
# observation: [-0.0364012  -0.8068354   1.4113803  -0.55304784 -0.14001271  0.08954775
#  -0.3016036   0.75118524  0.        ]
# action:      2  com:no_com
# reward:      -0.05759290343056021
#
# step 103
# observation: [ 0.4726991  -0.60512656  1.3641104  -0.49253517 -0.18728262  0.1500604
#  -0.3488735   0.8116979   0.        ]
# action:      2  com:no_com
# reward:      -0.11258311467408033
#
# step 104
# observation: [ 0.8545243  -0.4538449   1.2786579  -0.44715068 -0.27273506  0.1954449
#  -0.43432593  0.8570824   0.        ]
# action:      2  com:no_com
# reward:      -0.20229566556195872
#
# step 105
# observation: [ 1.1408932  -0.34038368  1.1645687  -0.4131123  -0.38682437  0.22948326
#  -0.54841524  0.8911208   0.        ]
# action:      1  com:no_com
# reward:      -0.2434456089516193
#
# step 106
# observation: [ 0.35566995 -0.25528777  1.1290016  -0.38758352 -0.42239136  0.25501204
#  -0.5839822   0.9166496   0.        ]
# action:      4  com:no_com
# reward:      -0.2519079117987542
#
# step 107
# observation: [ 0.26675245  0.30853418  1.1023264  -0.41843694 -0.4490666   0.22415861
#  -0.6106575   0.8857961   0.        ]
# action:      2  com:no_com
# reward:      -0.30984529024739693
#
# step 108
# observation: [ 0.70006436  0.23140064  1.0323199  -0.44157702 -0.51907307  0.20101856
#  -0.68066394  0.86265606  0.        ]
# action:      1  com:no_com
# reward:      -0.3057757635277348
#
# step 109
# observation: [ 0.02504825  0.17355047  1.0298151  -0.45893207 -0.5215779   0.18366352
#  -0.68316877  0.84530103  0.        ]
# action:      4  com:no_com
# reward:      -0.2885624527476315
#
# step 110
# observation: [ 0.01878619  0.63016284  1.0279365  -0.52194834 -0.5234565   0.12064722
#  -0.6850474   0.78228474  0.        ]
# action:      4  com:no_com
# reward:      -0.2760306067270891
#
# step 111
# observation: [ 0.01408964  0.97262216  1.0265275  -0.61921054 -0.52486545  0.02338501
#  -0.6864563   0.68502253  0.        ]
# action:      4  com:no_com
# reward:      -0.28650666175048295
#
# step 112
# observation: [ 0.01056723  1.2294666   1.0254709  -0.7421572  -0.5259222  -0.09956165
#  -0.68751305  0.56207585  0.        ]
# action:      4  com:no_com
# reward:      -0.33588192743348927
#
# step 113
# observation: [ 0.00792542  1.4221      1.0246782  -0.8843672  -0.52671474 -0.24177164
#  -0.6883056   0.41986588  0.        ]
# action:      3  com:no_com
# reward:      -0.36711487061555137
#
# step 114
# observation: [ 0.00594407  0.566575    1.0240839  -0.9410247  -0.5273091  -0.29842913
#  -0.6889      0.36320838  0.        ]
# action:      3  com:no_com
# reward:      -0.36316103470819133
#
# step 115
# observation: [ 0.00445805 -0.07506878  1.023638   -0.9335178  -0.52775496 -0.29092225
#  -0.6893458   0.37071526  0.        ]
# action:      3  com:no_com
# reward:      -0.3342406716121147
#
# step 116
# observation: [ 0.00334354 -0.5563016   1.0233037  -0.87788767 -0.5280893  -0.2352921
#  -0.68968016  0.4263454   0.        ]
# action:      3  com:no_com
# reward:      -0.2997554100549949
#
# step 117
# observation: [ 0.00250765 -0.9172262   1.0230529  -0.78616506 -0.52834004 -0.14356948
#  -0.6899309   0.518068    0.        ]
# action:      1  com:no_com
# reward:      -0.2345808470318776
#
# step 118
# observation: [-0.49811926 -0.6879196   1.0728649  -0.7173731  -0.47852814 -0.07477752
#  -0.640119    0.58686     0.        ]
# action:      1  com:no_com
# reward:      -0.1535508069280965
#
# step 119
# observation: [-0.87358946 -0.5159397   1.1602238  -0.6657791  -0.3911692  -0.02318355
#  -0.55276006  0.63845396  0.        ]
# action:      0  com:com active
# reward:      -0.20628852608767004
#
# step 120
# observation: [-0.6551921  -0.38695478  1.225743   -0.62708366 -0.32564998  0.01551193
#  -0.48724085  0.6771494   8.        ]
# action:      4  com:no_com
# reward:      -0.07648797674652966
#
# step 121
# observation: [-0.49139407  0.2097839   1.2748824  -0.64806205 -0.27651057 -0.00546646
#  -0.43810144  0.656171    0.        ]
# action:      2  com:no_com
# reward:      -0.08435005714263653
#
# step 122
# observation: [ 0.13145445  0.15733793  1.261737   -0.6637958  -0.289656   -0.02120025
#  -0.4512469   0.64043725  0.        ]
# action:      2  com:no_com
# reward:      -0.12324984311658972
#
# step 123
# observation: [ 0.59859085  0.11800344  1.201878   -0.6755962  -0.3495151  -0.0330006
#  -0.51110595  0.6286369   0.        ]
# action:      2  com:no_com
# reward:      -0.19925121864174947
#
# step 124
# observation: [ 0.94894314  0.08850259  1.1069835  -0.68444645 -0.4444094  -0.04185086
#  -0.6060003   0.6197867   0.        ]
# action:      1  com:no_com
# reward:      -0.2191160114696015
#
# step 125
# observation: [ 0.21170735  0.06637694  1.0858128  -0.69108415 -0.46558014 -0.04848855
#  -0.62717104  0.613149    0.        ]
# action:      2  com:no_com
# reward:      -0.28530651567619464
#
# step 126
# observation: [ 0.6587805   0.0497827   1.0199348  -0.6960624  -0.5314582  -0.05346682
#  -0.6930491   0.6081707   0.        ]
# action:      3  com:no_com
# reward:      -0.3374580112836239
#
# step 127
# observation: [ 0.49408537 -0.46266297  0.9705263  -0.64979607 -0.58086675 -0.00720052
#  -0.7424576   0.654437    0.        ]
# action:      1  com:no_com
# reward:      -0.3232928973909028
#
# step 128
# observation: [-0.12943596 -0.34699723  0.98346984 -0.6150964  -0.5679231   0.0274992
#  -0.729514    0.6891367   0.        ]
# action:      1  com:no_com
# reward:      -0.2611477526151034
#
# step 129
# observation: [-0.59707695 -0.26024792  1.0431776  -0.5890716  -0.5082154   0.05352399
#  -0.6698063   0.7151615   0.        ]
# action:      0  com:com active
# reward:      -0.3201069113601594
#
# step 130
# observation: [-0.44780773 -0.19518594  1.0879583  -0.56955296 -0.46343467  0.07304259
#  -0.6250255   0.7346801   8.        ]
# action:      2  com:no_com
# reward:      -0.23794319904945288
#
# step 131
# observation: [ 0.1641442  -0.14638945  1.0715439  -0.55491406 -0.4798491   0.08768153
#  -0.64144     0.749319    0.        ]
# action:      1  com:no_com
# reward:      -0.20523932255752084
#
# step 132
# observation: [-0.37689185 -0.10979209  1.1092331  -0.5439348  -0.4421599   0.09866074
#  -0.60375077  0.76029825  0.        ]
# action:      1  com:no_com
# reward:      -0.14384469934655897
#
# step 133
# observation: [-0.7826689  -0.08234407  1.1875     -0.53570044 -0.363893    0.10689515
#  -0.5254839   0.76853263  0.        ]
# action:      4  com:no_com
# reward:      -0.09712062023214428
#
# step 134
# observation: [-0.5870017   0.43824196  1.2462002  -0.57952464 -0.30519286  0.06307095
#  -0.46678373  0.72470844  0.        ]
# action:      1  com:no_com
# reward:      -0.045504017307675136
#
# step 135
# observation: [-0.94025123  0.32868147  1.3402252  -0.6123928  -0.21116772  0.03020281
#  -0.3727586   0.6918403   0.        ]
# action:      4  com:no_com
# reward:      -0.021757759245621528
#
# step 136
# observation: [-0.70518845  0.7465111   1.4107441  -0.68704385 -0.14064889 -0.0444483
#  -0.30223975  0.6171892   0.        ]
# action:      4  com:no_com
# reward:      -0.03033295449639447
#
# step 137
# observation: [-0.5288913   1.0598834   1.4636333  -0.7930322  -0.08775975 -0.15043664
#  -0.24935062  0.5112009   0.        ]
# action:      0  com:com active
# reward:      -0.15517975876600984
#
# step 138
# observation: [-0.3966685   0.7949125   1.5033001  -0.8725234  -0.0480929  -0.22992788
#  -0.20968376  0.43170962  8.        ]
# action:      4  com:no_com
# reward:      -0.11562816096978194
#
# step 139
# observation: [-0.2975014   1.0961844   1.5330502  -0.9821419  -0.01834276 -0.33954632
#  -0.17993364  0.3220912   0.        ]
# action:      3  com:no_com
# reward:      -0.13822136773365842
#
# step 140
# observation: [-0.22312602  0.32213828  1.5553628  -1.0143558   0.00396984 -0.37176016
#  -0.15762103  0.28987736  0.        ]
# action:      3  com:no_com
# reward:      -0.12008967347881479
#
# step 141
# observation: [-0.16734453 -0.2583963   1.5720973  -0.9885161   0.02070429 -0.34592053
#  -0.14088657  0.31571698  0.        ]
# action:      2  com:no_com
# reward:      -0.10690928293255697
#
# step 142
# observation: [ 0.3744916  -0.19379722  1.5346482  -0.96913636 -0.01674487 -0.3265408
#  -0.17833574  0.33509672  0.        ]
# action:      0  com:com active
# reward:      -0.19935763244530846
#
# step 143
# observation: [ 0.2808687  -0.14534791  1.5065613  -0.9546016  -0.04483174 -0.312006
#  -0.20642261  0.34963152  8.        ]
# action:      0  com:com active
# reward:      -0.19500656844249734
#
# step 144
# observation: [ 0.21065153 -0.10901093  1.4854962  -0.9437005  -0.06589689 -0.3011049
#  -0.22748776  0.3605326   8.        ]
# action:      2  com:no_com
# reward:      -0.1031512250424652
#
# step 145
# observation: [ 0.65798867 -0.0817582   1.4196973  -0.93552464 -0.13169576 -0.29292908
#  -0.29328662  0.36870843  0.        ]
# action:      0  com:com active
# reward:      -0.21502990670526606
#
# step 146
# observation: [ 0.49349147 -0.06131865  1.3703481  -0.9293928  -0.1810449  -0.28679723
#  -0.34263578  0.3748403   8.        ]
# action:      0  com:com active
# reward:      -0.22718464938458072
#
# step 147
# observation: [ 0.37011862 -0.04598899  1.3333362  -0.9247939  -0.21805677 -0.28219834
#  -0.37964764  0.37943918  8.        ]
# action:      0  com:com active
# reward:      -0.2381264303246871
#
# step 148
# observation: [ 0.27758896 -0.03449174  1.3055773  -0.9213447  -0.24581566 -0.27874917
#  -0.40740654  0.38288835  8.        ]
# action:      1  com:no_com
# reward:      -0.12319625237626841
#
# step 149
# observation: [-0.29180828 -0.02586881  1.3347582  -0.91875786 -0.21663484 -0.27616227
#  -0.3782257   0.38547525  0.        ]
# action:      3  com:no_com
# reward:      -0.08820281175543193
#
# step 150
# observation: [-0.21885622 -0.5194016   1.3566438  -0.8668177  -0.1947492  -0.22422211
#  -0.35634008  0.4374154   0.        ]
# action:      3  com:no_com
# reward:      -0.05010053041731897
#
# step 151
# observation: [-0.16414216 -0.8895512   1.373058   -0.77786255 -0.178335   -0.13526699
#  -0.33992586  0.5263705   0.        ]
# action:      2  com:no_com
# reward:      -0.05136570531640269
#
# step 152
# observation: [ 0.37689337 -0.66716343  1.3353686  -0.71114624 -0.21602434 -0.06855065
#  -0.3776152   0.59308684  0.        ]
# action:      3  com:no_com
# reward:      -0.06066966438649247
#
# step 153
# observation: [ 0.28267005 -1.0003725   1.3071016  -0.61110896 -0.24429134  0.0314866
#  -0.4058822   0.6931241   0.        ]
# action:      3  com:no_com
# reward:      -0.09498258776535698
#
# step 154
# observation: [ 0.21200253 -1.2502794   1.2859014  -0.48608103 -0.2654916   0.15651454
#  -0.42708245  0.81815207  0.        ]
# action:      1  com:no_com
# reward:      -0.11618498804709343
#
# step 155
# observation: [-0.3409981  -0.93770957  1.3200012  -0.39231008 -0.23139179  0.2502855
#  -0.39298266  0.911923    0.        ]
# action:      2  com:no_com
# reward:      -0.16823545400450973
#
# step 156
# observation: [ 0.24425142 -0.7032822   1.2955761  -0.32198185 -0.25581694  0.3206137
#  -0.41740778  0.9822512   0.        ]
# action:      4  com:no_com
# reward:      -0.17971203791509094
#
# step 157
# observation: [ 0.18318857 -0.02746163  1.2772572  -0.31923568 -0.27413577  0.32335988
#  -0.43572664  0.9849974   0.        ]
# action:      2  com:no_com
# reward:      -0.2200573156041543
#
# step 158
# observation: [ 0.63739145 -0.02059622  1.213518   -0.31717607 -0.33787492  0.32541952
#  -0.4994658   0.98705703  0.        ]
# action:      0  com:com active
# reward:      -0.35565410679861054
#
# step 159
# observation: [ 0.47804356 -0.01544717  1.1657137  -0.31563136 -0.38567927  0.32696423
#  -0.5472701   0.98860174  8.        ]
# action:      0  com:com active
# reward:      -0.3853542312162608
#
# step 160
# observation: [ 0.35853267 -0.01158537  1.1298604  -0.31447282 -0.42153254  0.32812276
#  -0.58312345  0.9897603   8.        ]
# action:      4  com:no_com
# reward:      -0.2789190823022471
#
# step 161
# observation: [ 0.2688995   0.49131098  1.1029705  -0.36360392 -0.4484225   0.27899167
#  -0.61001337  0.9406292   0.        ]
# action:      1  com:no_com
# reward:      -0.2338509506050986
#
# step 162
# observation: [-0.29832536  0.36848322  1.1328031  -0.40045223 -0.41858995  0.24214333
#  -0.5801808   0.9037809   0.        ]
# action:      0  com:com active
# reward:      -0.3030000619625547
#
# step 163
# observation: [-0.22374402  0.27636242  1.1551775  -0.4280885  -0.39621556  0.21450709
#  -0.55780643  0.8761446   8.        ]
# action:      1  com:no_com
# reward:      -0.14607791308867282
#
# step 164
# observation: [-0.667808    0.20727181  1.2219583  -0.44881564 -0.32943475  0.19377992
#  -0.49102563  0.85541743  0.        ]
# action:      4  com:no_com
# reward:      -0.09448004393598708
#
# step 165
# observation: [-0.50085604  0.65545386  1.2720438  -0.514361   -0.27934915  0.12823452
#  -0.44094002  0.78987205  0.        ]
# action:      3  com:no_com
# reward:      -0.07512044502546847
#
# step 166
# observation: [-0.375642   -0.0084096   1.3096081  -0.51352006 -0.24178496  0.12907548
#  -0.40337583  0.790713    0.        ]
# action:      4  com:no_com
# reward:      -0.051983081638777434
#
# step 167
# observation: [-0.28173152  0.4936928   1.3377812  -0.56288934 -0.2136118   0.07970621
#  -0.3752027   0.74134374  0.        ]
# action:      0  com:com active
# reward:      -0.13887081512143545
#
# step 168
# observation: [-0.21129863  0.3702696   1.358911   -0.59991634 -0.19248194  0.04267925
#  -0.3540728   0.70431674  8.        ]
# action:      3  com:no_com
# reward:      -0.035412943292888265
#
# step 169
# observation: [-0.15847397 -0.2222978   1.3747585  -0.57768655 -0.17663454  0.06490903
#  -0.33822542  0.7265465   0.        ]
# action:      2  com:no_com
# reward:      -0.05277264916371095
#
# step 170
# observation: [ 0.38114452 -0.16672336  1.336644   -0.56101424 -0.214749    0.08158136
#  -0.37633985  0.7432189   0.        ]
# action:      1  com:no_com
# reward:      -0.046230460431670284
#
# step 171
# observation: [-0.2141416  -0.12504251  1.3580582  -0.54850996 -0.19333483  0.09408561
#  -0.3549257   0.7557231   0.        ]
# action:      3  com:no_com
# reward:      -0.054977285081135474
#
# step 172
# observation: [-0.1606062  -0.5937819   1.3741188  -0.48913178 -0.17727421  0.1534638
#  -0.33886507  0.8151013   0.        ]
# action:      4  com:no_com
# reward:      -0.049203782198469354
#
# step 173
# observation: [-0.12045465  0.05466359  1.3861643  -0.49459812 -0.16522874  0.14799744
#  -0.32681963  0.809635    0.        ]
# action:      4  com:no_com
# reward:      -0.03321354129195102
#
# step 174
# observation: [-0.09034099  0.5409977   1.3951983  -0.5486979  -0.15619464  0.09389768
#  -0.31778553  0.7555352   0.        ]
# action:      2  com:no_com
# reward:      -0.04261129284080818
#
# step 175
# observation: [ 0.43224427  0.40574828  1.3519739  -0.58927274 -0.19941907  0.05332285
#  -0.36100996  0.71496034  0.        ]
# action:      4  com:no_com
# reward:      -0.05448343478069831
#
# step 176
# observation: [ 0.3241832   0.8043112   1.3195556  -0.66970384 -0.23183739 -0.02710827
#  -0.39342827  0.63452923  0.        ]
# action:      0  com:com active
# reward:      -0.17325768888115967
#
# step 177
# observation: [ 0.24313739  0.6032334   1.2952418  -0.7300272  -0.25615114 -0.08743161
#  -0.417742    0.5742059   8.        ]
# action:      0  com:com active
# reward:      -0.19289033750712398
#
# step 178
# observation: [ 0.18235305  0.45242506  1.2770065  -0.7752697  -0.27438644 -0.13267411
#  -0.4359773   0.5289634   8.        ]
# action:      0  com:com active
# reward:      -0.21073780038007006
#
# step 179
# observation: [ 0.13676478  0.33931878  1.2633301  -0.80920154 -0.2880629  -0.166606
#  -0.44965377  0.4950315   8.        ]
# action:      0  com:com active
# reward:      -0.22588007176173308
#
# step 180
# observation: [ 0.10257359  0.2544891   1.2530727  -0.83465046 -0.29832026 -0.1920549
#  -0.45991114  0.46958262  8.        ]
# action:      1  com:no_com
# reward:      -0.1101235753041975
#
# step 181
# observation: [-0.4230698   0.19086681  1.2953798  -0.8537372  -0.2560133  -0.21114159
#  -0.41760415  0.45049593  0.        ]
# action:      2  com:no_com
# reward:      -0.12606187258717458
#
# step 182
# observation: [ 0.18269764  0.14315012  1.27711    -0.8680522  -0.27428305 -0.2254566
#  -0.43587393  0.43618092  0.        ]
# action:      1  com:no_com
# reward:      -0.1124241063332859
#
# step 183
# observation: [-0.36297676  0.10736258  1.3134077  -0.8787884  -0.23798539 -0.23619285
#  -0.39957625  0.42544466  0.        ]
# action:      2  com:no_com
# reward:      -0.1276525289082604
#
# step 184
# observation: [ 0.22776742  0.08052194  1.2906308  -0.88684064 -0.26076213 -0.24424505
#  -0.422353    0.41739246  0.        ]
# action:      3  com:no_com
# reward:      -0.11731142470284835
#
# step 185
# observation: [ 0.17082557 -0.43960854  1.2735484  -0.8428798  -0.27784467 -0.2002842
#  -0.43943554  0.46135333  0.        ]
# action:      1  com:no_com
# reward:      -0.08590942311528754
#
# step 186
# observation: [-0.37188083 -0.3297064   1.3107364  -0.8099091  -0.2406566  -0.16731356
#  -0.40224746  0.49432397  0.        ]
# action:      1  com:no_com
# reward:      -0.04682326524320332
#
# step 187
# observation: [-0.77891064 -0.24727981  1.3886274  -0.78518116 -0.16276553 -0.14258558
#  -0.3243564   0.51905197  0.        ]
# action:      2  com:no_com
# reward:      -0.039208889548024047
#
# step 188
# observation: [-0.08418296 -0.18545985  1.3970457  -0.7666352  -0.15434724 -0.12403959
#  -0.31593812  0.53759795  0.        ]
# action:      2  com:no_com
# reward:      -0.05134591237852213
#
# step 189
# observation: [ 0.43686277 -0.13909489  1.3533595  -0.75272566 -0.19803351 -0.1101301
#  -0.3596244   0.5515074   0.        ]
# action:      2  com:no_com
# reward:      -0.08878733072443279
#
# step 190
# observation: [ 0.8276471  -0.10432117  1.2705947  -0.74229354 -0.28079823 -0.09969798
#  -0.4423891   0.56193954  0.        ]
# action:      3  com:no_com
# reward:      -0.11931446416719303
#
# step 191
# observation: [ 0.6207353  -0.5782409   1.2085212  -0.68446946 -0.34287176 -0.04187389
#  -0.5044626   0.6197636   0.        ]
# action:      4  com:no_com
# reward:      -0.15400612938646746
#
# step 192
# observation: [ 0.4655515   0.06631934  1.1619661  -0.6911014  -0.38942692 -0.04850583
#  -0.55101776  0.6131317   0.        ]
# action:      0  com:com active
# reward:      -0.2829272940718768
#
# step 193
# observation: [ 0.34916362  0.04973951  1.1270497  -0.6960754  -0.42434326 -0.05347978
#  -0.58593416  0.60815775  8.        ]
# action:      0  com:com active
# reward:      -0.3062507764570951
#
# step 194
# observation: [ 0.2618727   0.03730463  1.1008625  -0.6998058  -0.45053053 -0.05721024
#  -0.6121214   0.6044273   8.        ]
# action:      4  com:no_com
# reward:      -0.23316253970866382
#
# step 195
# observation: [ 0.19640453  0.5279785   1.081222   -0.75260365 -0.470171   -0.11000809
#  -0.63176185  0.5516294   0.        ]
# action:      2  com:no_com
# reward:      -0.30850153025211385
#
# step 196
# observation: [ 0.6473034   0.39598384  1.0164917  -0.79220206 -0.5349013  -0.14960648
#  -0.6964922   0.512031    0.        ]
# action:      1  com:no_com
# reward:      -0.31671830402708284
#
# step 197
# observation: [-0.01452245  0.2969879   1.0179439  -0.82190084 -0.5334491  -0.17930527
#  -0.6950399   0.48233226  0.        ]
# action:      3  com:no_com
# reward:      -0.306383365554357
#
# step 198
# observation: [-0.01089184 -0.27725908  1.0190331  -0.7941749  -0.5323599  -0.15157935
#  -0.6939508   0.51005816  0.        ]
# action:      1  com:no_com
# reward:      -0.24898837026942686
#
# step 199
# observation: [-0.5081689  -0.20794432  1.06985    -0.7733805  -0.481543   -0.13078493
#  -0.6431339   0.5308526   0.        ]
# action:      4  com:no_com
# reward:      -0.223917912313753
#
# step 0
# observation: [ 0.          0.          0.5784319   0.6491301   0.6006349   1.2409122
#  -0.84865373  0.4064499   0.        ]
# action:      4  com:no_com
# reward:      -0.8472696823667175
#
# step 1
# observation: [ 0.          0.5         0.5784319   0.5991301   0.6006349   1.1909122
#  -0.84865373  0.35644993  0.        ]
# action:      4  com:no_com
# reward:      -0.7925471948371194
#
# step 2
# observation: [ 0.          0.875       0.5784319   0.5116301   0.6006349   1.1034122
#  -0.84865373  0.26894993  0.        ]
# action:      4  com:no_com
# reward:      -0.7437216644408651
#
# step 3
# observation: [ 0.          1.15625     0.5784319   0.3960051   0.6006349   0.9877872
#  -0.84865373  0.15332493  0.        ]
# action:      0  com:com active
# reward:      -0.8246495137139866
#
# step 4
# observation: [ 0.          0.8671875   0.5784319   0.30928636  0.6006349   0.90106845
#  -0.84865373  0.06660618  1.        ]
# action:      2  com:no_com
# reward:      -0.8075809581790273
#
# step 5
# observation: [ 0.5         0.6503906   0.5284319   0.24424727  0.55063486  0.8360294
#  -0.89865375  0.00156712  0.        ]
# action:      4  com:no_com
# reward:      -0.8858339891330302
#
# step 6
# observation: [ 0.375       0.98779297  0.4909319   0.14546798  0.5131349   0.7372501
#  -0.9361537  -0.09721218  0.        ]
# action:      2  com:no_com
# reward:      -1.058103858338775
#
# step 7
# observation: [ 0.78125     0.7408447   0.4128069   0.07138351  0.43500987  0.6631656
#  -1.0142788  -0.17129666  0.        ]
# action:      2  com:no_com
# reward:      -1.3123080393380355
#
# step 8
# observation: [ 1.0859375   0.55563354  0.30421314  0.01582015  0.32641613  0.60760224
#  -1.1228725  -0.22686     0.        ]
# action:      3  com:no_com
# reward:      -1.4981377769054804
#
# step 9
# observation: [ 0.8144531  -0.08327484  0.22276784  0.02414764  0.24497081  0.6159297
#  -1.2043178  -0.21853252  0.        ]
# action:      0  com:com active
# reward:      -1.7463073553512902
#
# step 10
# observation: [ 0.61083984 -0.06245613  0.16168386  0.03039325  0.18388683  0.62217534
#  -1.2654017  -0.2122869   1.        ]
# action:      1  com:no_com
# reward:      -1.6337615313513767
#
# step 11
# observation: [-0.04187012 -0.0468421   0.16587086  0.03507746  0.18807384  0.62685955
#  -1.2612147  -0.2076027   0.        ]
# action:      1  com:no_com
# reward:      -1.5010965222231298
#
# step 12
# observation: [-0.5314026  -0.03513157  0.21901113  0.03859062  0.2412141   0.6303727
#  -1.2080745  -0.20408954  0.        ]
# action:      2  com:no_com
# reward:      -1.524642246322385
#
# step 13
# observation: [ 0.10144806 -0.02634868  0.20886631  0.04122549  0.2310693   0.6330076
#  -1.2182193  -0.20145467  0.        ]
# action:      4  com:no_com
# reward:      -1.5648935825751318
#
# step 14
# observation: [ 0.07608604  0.4802385   0.20125772 -0.00679836  0.22346069  0.58498377
#  -1.2258279  -0.24947852  0.        ]
# action:      0  com:com active
# reward:      -1.698185072238347
#
# step 15
# observation: [ 0.05706453  0.36017886  0.19555126 -0.04281625  0.21775423  0.5489659
#  -1.2315344  -0.2854964   8.        ]
# action:      1  com:no_com
# reward:      -1.503817700279296
#
# step 16
# observation: [-0.4572016   0.27013415  0.24127142 -0.06982967  0.2634744   0.52195245
#  -1.1858141  -0.31250983  0.        ]
# action:      2  com:no_com
# reward:      -1.5543959046011562
#
# step 17
# observation: [ 0.1570988   0.20260061  0.22556154 -0.09008972  0.24776451  0.5016924
#  -1.201524   -0.3327699   0.        ]
# action:      4  com:no_com
# reward:      -1.6304887185954136
#
# step 18
# observation: [ 0.1178241   0.6519505   0.21377914 -0.15528478  0.2359821   0.43649733
#  -1.2133064  -0.39796492  0.        ]
# action:      2  com:no_com
# reward:      -1.8180335087053043
#
# step 19
# observation: [ 0.58836806  0.48896286  0.15494232 -0.20418106  0.1771453   0.38760105
#  -1.2721432  -0.4468612   0.        ]
# action:      2  com:no_com
# reward:      -2.1005007504834117
#
# step 20
# observation: [ 0.9412761   0.36672214  0.06081472 -0.24085326  0.08301769  0.35092884
#  -1.3662709  -0.48353344  0.        ]
# action:      0  com:com active
# reward:      -2.42574505711865
#
# step 21
# observation: [ 0.70595706  0.2750416  -0.00978099 -0.26835743  0.01242199  0.3234247
#  -1.4368666  -0.5110376   6.        ]
# action:      1  com:no_com
# reward:      -2.3557310037429313
#
# step 22
# observation: [ 0.02946778  0.2062812  -0.01272776 -0.28898555  0.00947521  0.30279657
#  -1.4398134  -0.5316657   0.        ]
# action:      1  com:no_com
# reward:      -2.237088008362915
#
# step 23
# observation: [-0.47789916  0.1547109   0.03506215 -0.30445665  0.05726513  0.28732547
#  -1.3920234  -0.5471368   0.        ]
# action:      1  com:no_com
# reward:      -2.0182993993224323
#
# step 24
# observation: [-0.85842437  0.11603317  0.12090459 -0.31605995  0.14310756  0.27572215
#  -1.3061811  -0.55874014  0.        ]
# action:      4  com:no_com
# reward:      -1.9233006270623068
#
# step 25
# observation: [-0.64381826  0.58702487  0.18528642 -0.37476245  0.20748939  0.21701966
#  -1.2417992  -0.6174426   0.        ]
# action:      2  com:no_com
# reward:      -1.9838660207903624
#
# step 26
# observation: [ 0.01713629  0.44026867  0.18357278 -0.4187893   0.20577577  0.1729928
#  -1.2435129  -0.66146946  0.        ]
# action:      3  com:no_com
# reward:      -1.9648890620024462
#
# step 27
# observation: [ 0.01285222 -0.16979851  0.18228757 -0.40180945  0.20449054  0.18997265
#  -1.2447981  -0.64448965  0.        ]
# action:      2  com:no_com
# reward:      -2.078113121510284
#
# step 28
# observation: [ 0.50963914 -0.12734888  0.13132365 -0.38907456  0.15352662  0.20270754
#  -1.295762   -0.63175476  0.        ]
# action:      1  com:no_com
# reward:      -2.0357545169594617
#
# step 29
# observation: [-0.11777063 -0.09551166  0.14310071 -0.3795234   0.16530369  0.21225871
#  -1.2839849  -0.6222036   0.        ]
# action:      3  com:no_com
# reward:      -1.945283319319919
#
# step 30
# observation: [-0.08832797 -0.57163376  0.1519335  -0.32236004  0.17413649  0.26942208
#  -1.2751521  -0.5650402   0.        ]
# action:      1  com:no_com
# reward:      -1.757468361543012
#
# step 31
# observation: [-0.566246   -0.4287253   0.20855811 -0.2794875   0.23076108  0.3122946
#  -1.2185276  -0.5221677   0.        ]
# action:      4  com:no_com
# reward:      -1.6747292434181449
#
# step 32
# observation: [-0.4246845   0.17845602  0.25102657 -0.2973331   0.27322954  0.294449
#  -1.176059   -0.54001325  0.        ]
# action:      4  com:no_com
# reward:      -1.6732998219515434
#
# step 33
# observation: [-0.31851336  0.633842    0.2828779  -0.3607173   0.30508086  0.23106481
#  -1.1442077  -0.6033975   0.        ]
# action:      3  com:no_com
# reward:      -1.616238778849674
#
# step 34
# observation: [-0.23888502 -0.02461849  0.3067664  -0.35825545  0.32896936  0.23352666
#  -1.1203192  -0.60093564  0.        ]
# action:      0  com:com active
# reward:      -1.6741999431472916
#
# step 35
# observation: [-0.17916377 -0.01846387  0.32468277 -0.35640907  0.34688574  0.23537304
#  -1.1024028  -0.5990892   7.        ]
# action:      0  com:com active
# reward:      -1.6430965988465163
#
# step 36
# observation: [-0.13437283 -0.0138479   0.33812004 -0.35502428  0.36032304  0.23675783
#  -1.0889655  -0.59770447  7.        ]
# action:      1  com:no_com
# reward:      -1.4146198330463033
#
# step 37
# observation: [-0.6007796  -0.01038592  0.398198   -0.3539857   0.42040098  0.23779643
#  -1.0288876  -0.59666586  0.        ]
# action:      4  com:no_com
# reward:      -1.3850896518697886
#
# step 38
# observation: [-0.4505847   0.49221057  0.4432565  -0.40320674  0.46545947  0.18857537
#  -0.98382914 -0.6458869   0.        ]
# action:      2  com:no_com
# reward:      -1.4662900775454708
#
# step 39
# observation: [ 0.16206147  0.3691579   0.42705035 -0.44012254  0.44925332  0.15165958
#  -1.0000353  -0.6828027   0.        ]
# action:      3  com:no_com
# reward:      -1.4607747998149005
#
# step 40
# observation: [ 0.1215461  -0.22313157  0.41489574 -0.41780937  0.4370987   0.17397274
#  -1.0121899  -0.66048956  0.        ]
# action:      0  com:com active
# reward:      -1.5574857065854637
#
# step 41
# observation: [ 0.09115957 -0.16734867  0.40577978 -0.4010745   0.42798275  0.1907076
#  -1.0213058  -0.64375466  8.        ]
# action:      1  com:no_com
# reward:      -1.355181248266522
#
# step 42
# observation: [-0.4316303  -0.1255115   0.4489428  -0.38852337  0.47114578  0.20325875
#  -0.9781428  -0.63120353  0.        ]
# action:      2  com:no_com
# reward:      -1.3781819679269842
#
# step 43
# observation: [ 0.17627726 -0.09413363  0.43131506 -0.37911     0.45351806  0.21267211
#  -0.9957705  -0.6217902   0.        ]
# action:      1  com:no_com
# reward:      -1.297557518782252
#
# step 44
# observation: [-0.36779204 -0.07060022  0.4680943  -0.37205     0.49029726  0.21973214
#  -0.95899135 -0.6147301   0.        ]
# action:      4  com:no_com
# reward:      -1.3023735459699795
#
# step 45
# observation: [-0.27584404  0.44704983  0.4956787  -0.41675496  0.5178817   0.17502715
#  -0.9314069  -0.6594351   0.        ]
# action:      4  com:no_com
# reward:      -1.3814037105121404
#
# step 46
# ...
# reward:      -0.12673264123075062
#
# step 119
# observation: [-0.2497791  -0.06938633  0.60258806  0.9630954  -0.155301   -0.05112965
#   0.3021046  -0.4415231   2.        ]
# action:      2  com:no_com
# reward:      -0.036916624034468916
#
# step 120
# observation: [ 0.31266567 -0.05203975  0.5713215   0.9682994  -0.18656756 -0.04592567
#   0.27083802 -0.43631914  0.        ]
# action:      4  com:no_com
# reward:      -0.052575522421673244
#
# step 121
# observation: [ 0.23449925  0.4609702   0.5478716   0.92220235 -0.21001749 -0.09202269
#   0.24738811 -0.48241615  0.        ]
# action:      1  com:no_com
# reward:      -0.04756992257996151
#
# step 122
# observation: [-0.32412556  0.34572765  0.5802841   0.88762957 -0.17760493 -0.12659545
#   0.27980065 -0.51698893  0.        ]
# action:      2  com:no_com
# reward:      -0.06459295228674644
#
# step 123
# observation: [ 0.25690582  0.25929573  0.55459356  0.8617     -0.20329551 -0.15252504
#   0.25411007 -0.5429185   0.        ]
# action:      3  com:no_com
# reward:      -0.06441171131749215
#
# step 124
# observation: [ 0.19267938 -0.3055282   0.53532565  0.89225286 -0.22256346 -0.12197221
#   0.23484214 -0.51236564  0.        ]
# action:      0  com:com active
# reward:      -0.16598823638596855
#
# step 125
# observation: [ 0.14450952 -0.22914615  0.5208747   0.91516745 -0.23701441 -0.09905759
#   0.22039118 -0.48945105  2.        ]
# action:      2  com:no_com
# reward:      -0.0954191487475415
#
# step 126
# observation: [ 0.60838217 -0.1718596   0.46003646  0.93235344 -0.29785264 -0.08187164
#   0.15955298 -0.4722651   0.        ]
# action:      1  com:no_com
# reward:      -0.09088980213391905
#
# step 127
# observation: [-0.04371339 -0.12889472  0.4644078   0.9452429  -0.2934813  -0.06898216
#   0.1639243  -0.45937562  0.        ]
# action:      3  com:no_com
# reward:      -0.08430442297514674
#
# step 128
# observation: [-0.03278504 -0.59667104  0.4676863   1.00491    -0.29020277 -0.00931506
#   0.16720282 -0.3997085   0.        ]
# action:      4  com:no_com
# reward:      -0.0830086835775382
#
# step 129
# observation: [-0.02458878  0.05249672  0.47014517  0.9996603  -0.2877439  -0.01456473
#   0.1696617  -0.4049582   0.        ]
# action:      1  com:no_com
# reward:      -0.05599101161687459
#
# step 130
# observation: [-0.51844156  0.03937254  0.52198935  0.99572307 -0.23589975 -0.01850199
#   0.22150585 -0.40889543  0.        ]
# action:      0  com:com active
# reward:      -0.1392758635163115
#
# step 131
# observation: [-0.3888312   0.02952941  0.56087244  0.99277014 -0.19701663 -0.02145493
#   0.26038897 -0.4118484   2.        ]
# action:      4  com:no_com
# reward:      -0.033602275305321755
#
# step 132
# observation: [-0.29162338  0.52214706  0.5900348   0.9405554  -0.16785428 -0.07366963
#   0.28955132 -0.46406308  0.        ]
# action:      0  com:com active
# reward:      -0.13404165713075328
#
# step 133
# observation: [-0.21871755  0.3916103   0.6119065   0.90139437 -0.14598253 -0.11283066
#   0.31142306 -0.50322413  2.        ]
# action:      3  com:no_com
# reward:      -0.025291747379784194
#
# step 134
# observation: [-0.16403815 -0.20629229  0.6283104   0.9220236  -0.12957871 -0.09220143
#   0.3278269  -0.48259488  0.        ]
# action:      4  com:no_com
# reward:      -0.029813994803472778
#
# step 135
# observation: [-0.12302862  0.3452808   0.6406132   0.8874955  -0.11727585 -0.12672952
#   0.34012973 -0.517123    0.        ]
# action:      3  com:no_com
# reward:      -0.022206530731509494
#
# step 136
# observation: [-0.09227146 -0.24103941  0.64984035  0.91159946 -0.10804871 -0.10262557
#   0.3493569  -0.493019    0.        ]
# action:      3  com:no_com
# reward:      -0.011420480005494633
#
# step 137
# observation: [-0.0692036  -0.6807796   0.65676075  0.97967744 -0.10112835 -0.03454762
#   0.35627726 -0.42494106  0.        ]
# action:      0  com:com active
# reward:      -0.10947672244826875
#
# step 138
# observation: [-0.0519027  -0.51058465  0.661951    1.0307359  -0.09593807  0.01651085
#   0.3614675  -0.3738826   2.        ]
# action:      4  com:no_com
# reward:      -0.00849543580684755
#
# step 139
# observation: [-0.03892702  0.1170615   0.6658437   1.0190297  -0.09204537  0.0048047
#   0.36536023 -0.38558877  0.        ]
# action:      0  com:com active
# reward:      -0.10795921636706153
#
# step 140
# observation: [-0.02919527  0.08779612  0.6687632   1.0102501  -0.08912585 -0.00397491
#   0.36827976 -0.39436838  2.        ]
# action:      4  com:no_com
# reward:      -0.011225370840566948
#
# step 141
# observation: [-0.02189645  0.5658471   0.67095286  0.95366544 -0.0869362  -0.06055962
#   0.3704694  -0.45095307  0.        ]
# action:      2  com:no_com
# reward:      -0.028913077252569433
#
# step 142
# observation: [ 0.48357767  0.4243853   0.62259513  0.9112269  -0.13529396 -0.10299815
#   0.32211164 -0.4933916   0.        ]
# action:      0  com:com active
# reward:      -0.14761195415838935
#
# step 143
# observation: [ 0.36268324  0.31828898  0.5863268   0.879398   -0.1715623  -0.13482705
#   0.2858433  -0.5252205   2.        ]
# action:      3  com:no_com
# reward:      -0.05132235623873317
#
# step 144
# observation: [ 0.27201244 -0.26128325  0.55912554  0.90552634 -0.19876353 -0.10869873
#   0.25864205 -0.4990922   0.        ]
# action:      2  com:no_com
# reward:      -0.08038876321811506
#
# step 145
# observation: [ 0.70400935 -0.19596244  0.48872462  0.92512256 -0.26916447 -0.08910248
#   0.18824112 -0.47949594  0.        ]
# action:      2  com:no_com
# reward:      -0.14389423432075182
#
# step 146
# observation: [ 1.028007   -0.14697184  0.3859239   0.93981975 -0.37196517 -0.0744053
#   0.08544043 -0.46479875  0.        ]
# action:      4  com:no_com
# reward:      -0.21451556706032224
#
# step 147
# observation: [ 0.7710053   0.38977113  0.30882338  0.90084267 -0.4490657  -0.11338241
#   0.0083399  -0.5037759   0.        ]
# action:      3  com:no_com
# reward:      -0.26551615633486964
#
# step 148
# observation: [ 0.5782539  -0.20767166  0.250998    0.9216098  -0.5068911  -0.09261525
#  -0.04948549 -0.4830087   0.        ]
# action:      0  com:com active
# reward:      -0.40872135311226176
#
# step 149
# observation: [ 0.43369046 -0.15575375  0.20762894  0.93718517 -0.5502601  -0.07703988
#  -0.09285454 -0.46743333  2.        ]
# action:      1  com:no_com
# reward:      -0.2881336088562019
#
# step 150
# observation: [-0.17473216 -0.11681531  0.22510216  0.9488667  -0.5327869  -0.06535834
#  -0.07538132 -0.4557518   0.        ]
# action:      1  com:no_com
# reward:      -0.22380442546946028
#
# step 151
# observation: [-0.6310491  -0.08761148  0.28820708  0.95762783 -0.469682   -0.0565972
#  -0.01227641 -0.44699064  0.        ]
# action:      0  com:com active
# reward:      -0.28088495922018775
#
# step 152
# observation: [-0.47328684 -0.06570861  0.33553576  0.9641987  -0.42235333 -0.05002633
#   0.03505228 -0.4404198   2.        ]
# action:      0  com:com active
# reward:      -0.2516920340092992
#
# step 153
# observation: [-0.35496512 -0.04928146  0.37103227  0.9691269  -0.3868568  -0.04509819
#   0.07054879 -0.43549165  2.        ]
# action:      2  com:no_com
# reward:      -0.1700064115065708
#
# step 154
# observation: [ 0.23377615 -0.03696109  0.34765464  0.97282296 -0.41023442 -0.04140208
#   0.04717118 -0.43179554  0.        ]
# action:      1  com:no_com
# reward:      -0.1442006600047842
#
# step 155
# observation: [-0.3246679  -0.02772082  0.38012144  0.97559506 -0.37776762 -0.03863
#   0.07963797 -0.42902344  0.        ]
# action:      4  com:no_com
# reward:      -0.13239502186858562
#
# step 156
# observation: [-0.24350092  0.4792094   0.40447155  0.9276741  -0.35341755 -0.08655094
#   0.10398806 -0.4769444   0.        ]
# action:      4  com:no_com
# reward:      -0.14208222017852432
#
# step 157
# observation: [-0.18262568  0.85940707  0.4227341   0.8417334  -0.33515498 -0.17249164
#   0.12225062 -0.5628851   0.        ]
# action:      2  com:no_com
# reward:      -0.19412503878418402
#
# step 158
# observation: [ 0.36303073  0.6445553   0.38643104  0.7772779  -0.37145805 -0.23694716
#   0.08594755 -0.6273406   0.        ]
# action:      3  com:no_com
# reward:      -0.21431083357535707
#
# step 159
# observation: [ 0.27227306 -0.01658354  0.35920373  0.77893627 -0.39868534 -0.23528881
#   0.05872025 -0.6256823   0.        ]
# action:      0  com:com active
# reward:      -0.33042677979262847
#
# step 160
# observation: [ 0.20420478 -0.01243766  0.33878323  0.78018004 -0.41910583 -0.23404504
#   0.03829977 -0.6244385   2.        ]
# action:      1  com:no_com
# reward:      -0.20212095820243642
#
# step 161
# observation: [-0.3468464  -0.00932824  0.3734679   0.78111285 -0.3844212  -0.23311222
#   0.0729844  -0.62350565  0.        ]
# action:      3  com:no_com
# reward:      -0.16173044307303927
#
# step 162
# observation: [-0.26013482 -0.50699615  0.39948136  0.83181244 -0.3584077  -0.18241261
#   0.09899789 -0.57280606  0.        ]
# action:      1  com:no_com
# reward:      -0.10430968460730415
#
# step 163
# observation: [-0.6951011  -0.38024715  0.4689915   0.86983716 -0.2888976  -0.14438789
#   0.168508   -0.53478134  0.        ]
# action:      0  com:com active
# reward:      -0.1694833795290858
#
# step 164
# observation: [-0.5213258  -0.28518534  0.52112406  0.8983557  -0.23676501 -0.11586936
#   0.22064058 -0.50626284  2.        ]
# action:      0  com:com active
# reward:      -0.14799823659165615
#
# step 165
# observation: [-0.39099437 -0.21388902  0.5602235   0.9197446  -0.19766557 -0.09448045
#   0.25974002 -0.48487392  2.        ]
# action:      4  com:no_com
# reward:      -0.044835211749248094
#
# step 166
# observation: [-0.2932458   0.33958325  0.58954805  0.8857863  -0.168341   -0.12843877
#   0.2890646  -0.5188322   0.        ]
# action:      2  com:no_com
# reward:      -0.06223989165974833
#
# step 167
# observation: [ 0.28006566  0.25468743  0.5615415   0.8603175  -0.19634756 -0.15390752
#   0.26105803 -0.544301    0.        ]
# action:      0  com:com active
# reward:      -0.1771742464344618
#
# step 168
# observation: [ 0.21004926  0.19101557  0.5405366   0.84121597 -0.2173525  -0.17300908
#   0.2400531  -0.56340253  2.        ]
# action:      0  com:com active
# reward:      -0.18943298773903092
#
# step 169
# observation: [ 0.15753694  0.14326169  0.5247829   0.8268898  -0.23310618 -0.18733525
#   0.22429942 -0.5777287   2.        ]
# action:      3  com:no_com
# reward:      -0.08191416756793922
#
# step 170
# observation: [ 0.1181527  -0.39255375  0.51296765  0.8661452  -0.24492146 -0.14807987
#   0.21248414 -0.5384733   0.        ]
# action:      1  com:no_com
# reward:      -0.05560252950314927
#
# step 171
# observation: [-0.41138548 -0.2944153   0.5541062   0.8955867  -0.2037829  -0.11863834
#   0.25362268 -0.5090318   0.        ]
# action:      3  com:no_com
# reward:      -0.03207201031639619
#
# step 172
# observation: [-0.3085391  -0.7208115   0.5849601   0.9676679  -0.172929   -0.0465572
#   0.2844766  -0.43695065  0.        ]
# action:      1  com:no_com
# reward:      -0.010014062575504792
#
# step 173
# observation: [-0.7314043  -0.5406086   0.6581005   1.0217288  -0.09978856  0.00750367
#   0.35761702 -0.38288978  0.        ]
# action:      0  com:com active
# reward:      -0.10432773249723924
#
# step 174
# observation: [-0.5485532  -0.40545645  0.71295583  1.0622743  -0.04493324  0.04804931
#   0.41247237 -0.34234414  2.        ]
# action:      4  com:no_com
# reward:      -0.0008242662493462193
#
# step 175
# observation: [-0.41141492  0.19590765  0.75409734  1.0426836  -0.00379175  0.02845855
#   0.45361385 -0.3619349   0.        ]
# action:      4  com:no_com
# reward:      -0.0020454212902049533
#
# step 176
# observation: [-0.3085612   0.64693075  0.7849535   0.9779905   0.02706437 -0.03623453
#   0.48446998 -0.426628    0.        ]
# action:      2  com:no_com
# reward:      -0.007183339552621554
#
# step 177
# observation: [ 2.6857910e-01  4.8519805e-01  7.5809556e-01  9.2947072e-01
#   2.0646406e-04 -8.4754333e-02  4.5761207e-01 -4.7514778e-01
#   0.0000000e+00]
# action:      4  com:no_com
# reward:      -0.029687815476660585
#
# step 178
# observation: [ 0.20143433  0.8638985   0.7379521   0.8430809  -0.01993697 -0.17114419
#   0.43746862 -0.5615376   0.        ]
# action:      3  com:no_com
# reward:      -0.035800530933865676
#
# step 179
# observation: [ 0.15107575  0.1479239   0.72284454  0.8282885  -0.03504454 -0.18593659
#   0.42236105 -0.57633     0.        ]
# action:      2  com:no_com
# reward:      -0.04810934775558835
#
# step 180
# observation: [ 0.6133068   0.11094293  0.66151386  0.81719416 -0.09637523 -0.19703087
#   0.36103037 -0.58742434  0.        ]
# action:      3  com:no_com
# reward:      -0.04440425446854221
#
# step 181
# observation: [ 0.4599801  -0.4167928   0.6155158   0.8588735  -0.14237323 -0.1553516
#   0.31503236 -0.545745    0.        ]
# action:      3  com:no_com
# reward:      -0.03677325688919411
#
# step 182
# observation: [ 0.34498507 -0.8125946   0.5810173   0.9401329  -0.17687175 -0.07409213
#   0.28053385 -0.4644856   0.        ]
# action:      0  com:com active
# reward:      -0.14127864528085743
#
# step 183
# observation: [ 0.25873882 -0.6094459   0.5551435   1.0010775  -0.20274562 -0.01314754
#   0.25465998 -0.403541    2.        ]
# action:      4  com:no_com
# reward:      -0.04965520354603972
#
# step 184
# observation: [ 0.19405411  0.04291554  0.53573805  0.99678594 -0.22215104 -0.01743909
#   0.23525456 -0.40783253  0.        ]
# action:      3  com:no_com
# reward:      -0.05689026778245849
#
# step 185
# observation: [ 0.14554058 -0.46781334  0.52118397  1.0435673  -0.2367051   0.02934225
#   0.2207005  -0.3610512   0.        ]
# action:      1  com:no_com
# reward:      -0.04320491442288245
#
# step 186
# observation: [-0.39084455 -0.35086     0.56026846  1.0786533  -0.19762063  0.06442825
#   0.25978497 -0.3259652   0.        ]
# action:      4  com:no_com
# reward:      -0.029987316287389404
#
# step 187
# observation: [-0.29313344  0.23685499  0.5895818   1.0549678  -0.16830729  0.04074275
#   0.2890983  -0.3496507   0.        ]
# action:      1  com:no_com
# reward:      -0.009805999907948995
#
# step 188
# observation: [-0.71985006  0.17764124  0.6615668   1.0372037  -0.09632228  0.02297862
#   0.3610833  -0.36741483  0.        ]
# action:      0  com:com active
# reward:      -0.10188535709958438
#
# step 189
# observation: [-0.53988755  0.13323094  0.71555555  1.0238806  -0.04233353  0.00965553
#   0.41507205 -0.38073793  2.        ]
# action:      0  com:com active
# reward:      -0.10000350626118223
#
# step 190
# observation: [-4.0491566e-01  9.9923201e-02  7.5604713e-01  1.0138882e+00
#  -1.8419647e-03 -3.3679002e-04  4.5556363e-01 -3.9073023e-01
#   2.0000000e+00]
# action:      4  com:no_com
# reward:      -0.004158201220628885
#
# step 191
# observation: [-0.30368674  0.5749424   0.78641576  0.956394    0.02852671 -0.05783103
#   0.4859323  -0.44822448  0.        ]
# action:      3  com:no_com
# reward:      -0.005228096738669134
#
# step 192
# observation: [-0.22776505 -0.0687932   0.8091923   0.96327335  0.05130322 -0.05095171
#   0.50870883 -0.44134516  0.        ]
# action:      4  com:no_com
# reward:      -0.013852739106258779
#
# step 193
# observation: [-0.1708238   0.4484051   0.8262747   0.91843283  0.06838559 -0.09579222
#   0.52579117 -0.48618567  0.        ]
# action:      0  com:com active
# reward:      -0.12334322460450722
#
# step 194
# observation: [-0.12811784  0.33630383  0.8390865   0.88480246  0.08119738 -0.1294226
#   0.53860295 -0.51981604  2.        ]
# action:      4  com:no_com
# reward:      -0.05012550475578641
#
# step 195
# observation: [-0.09608839  0.75222784  0.8486953   0.8095797   0.09080622 -0.2046454
#   0.5482118  -0.59503883  0.        ]
# action:      0  com:com active
# reward:      -0.17776013651113667
#
# step 196
# observation: [-0.07206629  0.5641709   0.8559019   0.75316256  0.09801285 -0.26106247
#   0.55541843 -0.65145594  1.        ]
# action:      3  com:no_com
# reward:      -0.07489428654100716
#
# step 197
# observation: [-0.05404972 -0.07687183  0.8613069   0.7608498   0.10341782 -0.2533753
#   0.56082344 -0.6437687   0.        ]
# action:      1  com:no_com
# reward:      -0.08610795614252505
#
# step 198
# observation: [-0.5405373  -0.05765387  0.9153606   0.76661515  0.15747155 -0.24760991
#   0.61487716 -0.63800335  0.        ]
# action:      0  com:com active
# reward:      -0.19839670526745157
#
# step 199
# observation: [-0.40540296 -0.0432404   0.9559009   0.7709392   0.19801185 -0.24328586
#   0.65541744 -0.63367933  1.        ]
# action:      3  com:no_com
# reward:      -0.08829063761567983
#
# that all - part 4

# %% [markdown]
# ## Method Weaknesses, Issues and Failures
#
# - Adding complexity, to a complexed problem. 5 stages, all must be reasonable for a good communication model
# - sending the wrong message or too much information can result in worse performence
# - Does not worth the effort when a central 'brain' available
# - Implicit COM - domain knowlege (and ussualy obs space of other agents) dependant
# - Communication (explicit) is exposed to Noise, Jamming, and Spoofing
